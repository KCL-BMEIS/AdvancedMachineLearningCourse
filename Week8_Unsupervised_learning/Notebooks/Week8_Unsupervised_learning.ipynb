# %% [markdown]
# # Week 8 - Unsupervised Learning
#
# ### ***CODING STYLE EXPLANATION | PLEASE READ CAREFULLY TO MAKE YOUR LIFE EASIER | THIS CODE IS FOR DESCIPTIVE PURPOSES ONLY***
#
# In this notebook a different coding style is being used compared to the other ones. Generally one can trivially write a classifier network as follow:

# %%
class ToyClassifierNetwork(nn.Module):
  def __init__(self, in_channels, conv_out_channels, no_classes, image_size=96):

    super(ToyClassifierNetwork, self).__init__()
    self.conv1 = nn.Conv2d(
        in_channels=in_channels, 
        out_channels=conv_out_channels, 
        kernel_size=3, 
        stride= 2,
        padding=1, 
    )
    
    self.conv2 =  nn.Conv2d(
        in_channels=conv_out_channels, 
        out_channels=conv_out_channels*2, 
        kernel_size=3, 
        stride=2,
        padding=1, 
    ) 

    in_features = (image_size/2**2)**2*conv_out_channels*2

    self.linear1 = nn.Linear(
        in_features=in_features
        out_features=in_features//2
    )

    self.linear2 = nn.Linear(
        in_features=in_features//2,
        out_features=3
    )
    
    self.activation = nn.LeakyReLU(inplace=False)

    torch.nn.init.xavier_normal_(self.conv1.weight.data)
    torch.nn.init.xavier_normal_(self.conv2.weight.data)
    torch.nn.init.xavier_normal_(self.linear1.weight.data)
    torch.nn.init.xavier_normal_(self.linear2.weight.data)

  def forward(self, x):
    out = self.conv1(x)
    out = self.activation(out)

    out = self.conv2(out)
    out = self.activation(out)

    out = torch.flatten(out, start_dim=1)

    out = self.linear1(out)
    out = self.activation(out)

    out = self.linear2(out)

    return out

# %% [markdown]
# But one can use torch's Dictionaries or Lists to store programatically defined network layers. It helps you have more control over the network structure without risking introducing bugs every time you want to add or substract just a few layers. That will look as follows:

# %%
class ToyClassifierNetwork(nn.Module):
  def __init__(
      self, 
      in_channels, 
      conv_out_channels,
      no_classes,
      no_convolutions=2, 
      no_linears=2, 
      image_size=96
  ):

    super(ToyClassifierNetwork, self).__init__()
    
    layers = torch.nn.ModuleDict()

    self.no_convolutions=no_convolutions
    self.no_linears=no_linears

    out_channels = conv_out_channels

    for i in range(no_convolutions):
      layers[f"conv_{i}"] = nn.Conv2d(
          in_channels=in_channels, 
          out_channels=out_channels, 
          kernel_size=3, 
          stride= 2,
          padding=1, 
      )
      in_channels = out_channels
      out_channels = out_channels*2
    
    in_features = (image_size/2**no_convolutions)**2*out_channels
    out_features = in_channels // 2 
    for i in range(no_linears-1):
      layers[f"linear_{i}"] = nn.Linear(
        in_features=in_features
        out_features=out_features
      )
      in_features = out_features
      out_features = out_features//2


    layers[f"linear_{i+1}"] = nn.Linear(
      in_features=out_features
      out_features=3
    )
    
    self.activation = nn.LeakyReLU(inplace=False)

    for m in self.modules():
      torch.nn.init.xavier_normal_(self.m.weight.data)

  def forward(self, x):
    out=x
    for i in range(self.no_convolutions):
        out=layers[f"conv_{i}"](out)
        out = self.activation(out)

    for i in range(self.no_linears-1)
        out=layers[f"linear_{i}"](out)
        out = self.activation(out)

    out = layers[f"linear_{i+1}"](out)

    return out

# %% [markdown]
# # Needed Setup
# To setup the data folder, just run the following cell

# %%
file_download_link = "https://github.com/KCL-BMEIS/AdvancedMachineLearningCourse/blob/main/Week8_Unsupervised_learning/Data/Week8_data.zip?raw=true"
# !wget -O Week8_data.zip --no-check-certificate "$file_download_link"
# !unzip Week8_data.zip
# Out:
# --2021-03-08 12:38:02--  https://github.com/KCL-BMEIS/AdvancedMachineLearningCourse/blob/main/Week8_Unsupervised_learning/Data/Week8_data.zip?raw=true
# Resolving github.com (github.com)... 140.82.121.3
# Connecting to github.com (github.com)|140.82.121.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://github.com/KCL-BMEIS/AdvancedMachineLearningCourse/raw/main/Week8_Unsupervised_learning/Data/Week8_data.zip [following]
# --2021-03-08 12:38:03--  https://github.com/KCL-BMEIS/AdvancedMachineLearningCourse/raw/main/Week8_Unsupervised_learning/Data/Week8_data.zip
# Reusing existing connection to github.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/KCL-BMEIS/AdvancedMachineLearningCourse/main/Week8_Unsupervised_learning/Data/Week8_data.zip [following]
# --2021-03-08 12:38:03--  https://raw.githubusercontent.com/KCL-BMEIS/AdvancedMachineLearningCourse/main/Week8_Unsupervised_learning/Data/Week8_data.zip
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.108.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 85178185 (81M) [application/zip]
# Saving to: ‘Week8_data.zip’
#
# Week8_data.zip      100%[===================>]  81.23M  1.64MB/s    in 1m 50s
#
# 2021-03-08 12:39:56 (754 KB/s) - ‘Week8_data.zip’ saved [85178185/85178185]
#
# Archive:  Week8_data.zip
#    creating: testing/
#   inflating: __MACOSX/._testing
#   inflating: testing/011_S_0005_ADNI1_M_7380_15T_HC_32245.nii.gz
#   inflating: __MACOSX/testing/._011_S_0005_ADNI1_M_7380_15T_HC_32245.nii.gz
#   inflating: testing/019_S_4252_ADNI2_F_8660_30T_AD_297290.nii.gz
#   inflating: __MACOSX/testing/._019_S_4252_ADNI2_F_8660_30T_AD_297290.nii.gz
#   inflating: testing/128_S_0225_ADNI1_F_8243_15T_MCI_68840.nii.gz
#   inflating: __MACOSX/testing/._128_S_0225_ADNI1_F_8243_15T_MCI_68840.nii.gz
#   inflating: testing/127_S_4604_ADNI2_M_6507_30T_HC_291900.nii.gz
#   inflating: __MACOSX/testing/._127_S_4604_ADNI2_M_6507_30T_HC_291900.nii.gz
#   inflating: testing/033_S_0906_ADNI1_F_6534_15T_MCI_42467.nii.gz
#   inflating: __MACOSX/testing/._033_S_0906_ADNI1_F_6534_15T_MCI_42467.nii.gz
#   inflating: testing/109_S_1157_ADNI1_F_8499_15T_AD_66157.nii.gz
#   inflating: __MACOSX/testing/._109_S_1157_ADNI1_F_8499_15T_AD_66157.nii.gz
#   inflating: testing/128_S_2220_ADNIGO_M_8217_30T_MCI_223525.nii.gz
#   inflating: __MACOSX/testing/._128_S_2220_ADNIGO_M_8217_30T_MCI_223525.nii.gz
#   inflating: testing/133_S_0433_ADNI1_F_8563_29T_HC_39960.nii.gz
#   inflating: __MACOSX/testing/._133_S_0433_ADNI1_F_8563_29T_HC_39960.nii.gz
#   inflating: testing/141_S_2333_ADNIGO_M_6711_30T_MCI_225435.nii.gz
#   inflating: __MACOSX/testing/._141_S_2333_ADNIGO_M_6711_30T_MCI_225435.nii.gz
#   inflating: testing/116_S_1243_ADNI1_M_7739_15T_MCI_59734.nii.gz
#   inflating: __MACOSX/testing/._116_S_1243_ADNI1_M_7739_15T_MCI_59734.nii.gz
#   inflating: testing/128_S_4745_ADNI2_F_6144_30T_MCI_312673.nii.gz
#   inflating: __MACOSX/testing/._128_S_4745_ADNI2_F_6144_30T_MCI_312673.nii.gz
#   inflating: testing/136_S_0186_ADNI1_F_8052_15T_HC_40200.nii.gz
#   inflating: __MACOSX/testing/._136_S_0186_ADNI1_F_8052_15T_HC_40200.nii.gz
#   inflating: testing/072_S_4941_ADNI2_M_6031_30T_MCI_340527.nii.gz
#   inflating: __MACOSX/testing/._072_S_4941_ADNI2_M_6031_30T_MCI_340527.nii.gz
#   inflating: testing/128_S_4842_ADNI2_F_7309_30T_MCI_322939.nii.gz
#   inflating: __MACOSX/testing/._128_S_4842_ADNI2_F_7309_30T_MCI_322939.nii.gz
#   inflating: testing/116_S_0890_ADNI1_F_5979_15T_MCI_59780.nii.gz
#   inflating: __MACOSX/testing/._116_S_0890_ADNI1_F_5979_15T_MCI_59780.nii.gz
#   inflating: testing/109_S_4260_ADNI2_F_7774_30T_MCI_263725.nii.gz
#   inflating: __MACOSX/testing/._109_S_4260_ADNI2_F_7774_30T_MCI_263725.nii.gz
#   inflating: testing/041_S_1411_ADNI1_M_7425_15T_MCI_80160.nii.gz
#   inflating: __MACOSX/testing/._041_S_1411_ADNI1_M_7425_15T_MCI_80160.nii.gz
#   inflating: testing/137_S_0301_ADNI1_F_7357_15T_HC_45877.nii.gz
#   inflating: __MACOSX/testing/._137_S_0301_ADNI1_F_7357_15T_HC_45877.nii.gz
#   inflating: testing/127_S_0754_ADNI1_F_6772_15T_AD_80759.nii.gz
#   inflating: __MACOSX/testing/._127_S_0754_ADNI1_F_6772_15T_AD_80759.nii.gz
#   inflating: testing/131_S_0319_ADNI1_F_7032_15T_HC_47983.nii.gz
#   inflating: __MACOSX/testing/._131_S_0319_ADNI1_F_7032_15T_HC_47983.nii.gz
#   inflating: testing/051_S_1123_ADNI1_F_7607_30T_HC_58052.nii.gz
#   inflating: __MACOSX/testing/._051_S_1123_ADNI1_F_7607_30T_HC_58052.nii.gz
#   inflating: testing/137_S_4756_ADNI2_M_8432_30T_AD_312660.nii.gz
#   inflating: __MACOSX/testing/._137_S_4756_ADNI2_M_8432_30T_AD_312660.nii.gz
#   inflating: testing/130_S_4883_ADNI2_F_7620_30T_MCI_326532.nii.gz
#   inflating: __MACOSX/testing/._130_S_4883_ADNI2_F_7620_30T_MCI_326532.nii.gz
#   inflating: testing/036_S_0945_ADNI1_M_7244_15T_MCI_36998.nii.gz
#   inflating: __MACOSX/testing/._036_S_0945_ADNI1_M_7244_15T_MCI_36998.nii.gz
#   inflating: testing/082_S_0304_ADNI1_F_7092_29T_HC_77068.nii.gz
#   inflating: __MACOSX/testing/._082_S_0304_ADNI1_F_7092_29T_HC_77068.nii.gz
#   inflating: testing/127_S_1140_ADNI1_M_8451_15T_MCI_63636.nii.gz
#   inflating: __MACOSX/testing/._127_S_1140_ADNI1_M_8451_15T_MCI_63636.nii.gz
#   inflating: testing/036_S_2378_ADNIGO_M_6002_30T_MCI_238656.nii.gz
#   inflating: __MACOSX/testing/._036_S_2378_ADNIGO_M_6002_30T_MCI_238656.nii.gz
#   inflating: testing/098_S_0896_ADNI1_M_7688_15T_HC_56030.nii.gz
#   inflating: __MACOSX/testing/._098_S_0896_ADNI1_M_7688_15T_HC_56030.nii.gz
#   inflating: testing/018_S_4733_ADNI2_M_7538_30T_AD_306752.nii.gz
#   inflating: __MACOSX/testing/._018_S_4733_ADNI2_M_7538_30T_AD_306752.nii.gz
#   inflating: testing/099_S_0492_ADNI1_M_8747_15T_AD_38769.nii.gz
#   inflating: __MACOSX/testing/._099_S_0492_ADNI1_M_8747_15T_AD_38769.nii.gz
#   inflating: testing/126_S_0784_ADNI1_F_7600_15T_AD_39004.nii.gz
#   inflating: __MACOSX/testing/._126_S_0784_ADNI1_F_7600_15T_AD_39004.nii.gz
#   inflating: testing/128_S_0216_ADNI1_M_8439_15T_AD_68834.nii.gz
#   inflating: __MACOSX/testing/._128_S_0216_ADNI1_M_8439_15T_AD_68834.nii.gz
#   inflating: testing/126_S_4458_ADNI2_F_7618_30T_MCI_281838.nii.gz
#   inflating: __MACOSX/testing/._126_S_4458_ADNI2_F_7618_30T_MCI_281838.nii.gz
#   inflating: testing/073_S_2182_ADNIGO_M_6563_30T_MCI_223288.nii.gz
#   inflating: __MACOSX/testing/._073_S_2182_ADNIGO_M_6563_30T_MCI_223288.nii.gz
#   inflating: testing/133_S_0493_ADNI1_M_7769_29T_HC_39972.nii.gz
#   inflating: __MACOSX/testing/._133_S_0493_ADNI1_M_7769_29T_HC_39972.nii.gz
#   inflating: testing/128_S_0200_ADNI1_M_6153_15T_MCI_68799.nii.gz
#   inflating: __MACOSX/testing/._128_S_0200_ADNI1_M_6153_15T_MCI_68799.nii.gz
#   inflating: testing/094_S_4162_ADNI2_F_7141_30T_MCI_254761.nii.gz
#   inflating: __MACOSX/testing/._094_S_4162_ADNI2_F_7141_30T_MCI_254761.nii.gz
#   inflating: testing/123_S_4170_ADNI2_F_6574_30T_MCI_254811.nii.gz
#   inflating: __MACOSX/testing/._123_S_4170_ADNI2_F_6574_30T_MCI_254811.nii.gz
#   inflating: testing/137_S_0283_ADNI1_M_7847_15T_HC_66427.nii.gz
#   inflating: __MACOSX/testing/._137_S_0283_ADNI1_M_7847_15T_HC_66427.nii.gz
#   inflating: testing/128_S_4607_ADNI2_F_5625_30T_HC_295860.nii.gz
#   inflating: __MACOSX/testing/._128_S_4607_ADNI2_F_5625_30T_HC_295860.nii.gz
#   inflating: testing/072_S_4102_ADNI2_F_6697_30T_MCI_248636.nii.gz
#   inflating: __MACOSX/testing/._072_S_4102_ADNI2_F_6697_30T_MCI_248636.nii.gz
#   inflating: testing/130_S_2391_ADNIGO_F_7184_30T_MCI_297600.nii.gz
#   inflating: __MACOSX/testing/._130_S_2391_ADNIGO_F_7184_30T_MCI_297600.nii.gz
#   inflating: testing/067_S_2301_ADNIGO_M_6584_30T_MCI_223058.nii.gz
#   inflating: __MACOSX/testing/._067_S_2301_ADNIGO_M_6584_30T_MCI_223058.nii.gz
#   inflating: testing/023_S_4115_ADNI2_M_6758_30T_MCI_255420.nii.gz
#   inflating: __MACOSX/testing/._023_S_4115_ADNI2_M_6758_30T_MCI_255420.nii.gz
#   inflating: testing/136_S_0429_ADNI1_M_6280_15T_MCI_40386.nii.gz
#   inflating: __MACOSX/testing/._136_S_0429_ADNI1_M_6280_15T_MCI_40386.nii.gz
#   inflating: testing/035_S_4784_ADNI2_F_8168_30T_MCI_313656.nii.gz
#   inflating: __MACOSX/testing/._035_S_4784_ADNI2_F_8168_30T_MCI_313656.nii.gz
#   inflating: testing/109_S_1343_ADNI1_M_6480_15T_MCI_66175.nii.gz
#   inflating: __MACOSX/testing/._109_S_1343_ADNI1_M_6480_15T_MCI_66175.nii.gz
#   inflating: testing/094_S_0692_ADNI1_F_7685_15T_HC_47294.nii.gz
#   inflating: __MACOSX/testing/._094_S_0692_ADNI1_F_7685_15T_HC_47294.nii.gz
#   inflating: testing/137_S_0631_ADNI1_M_7725_15T_MCI_46654.nii.gz
#   inflating: __MACOSX/testing/._137_S_0631_ADNI1_M_7725_15T_MCI_46654.nii.gz
#   inflating: testing/132_S_0339_ADNI1_M_8516_15T_MCI_94846.nii.gz
#   inflating: __MACOSX/testing/._132_S_0339_ADNI1_M_8516_15T_MCI_94846.nii.gz
#   inflating: testing/153_S_4125_ADNI2_F_7589_30T_HC_248630.nii.gz
#   inflating: __MACOSX/testing/._153_S_4125_ADNI2_F_7589_30T_HC_248630.nii.gz
#   inflating: testing/141_S_0717_ADNI1_M_7621_15T_HC_98887.nii.gz
#   inflating: __MACOSX/testing/._141_S_0717_ADNI1_M_7621_15T_HC_98887.nii.gz
#   inflating: testing/123_S_2055_ADNIGO_M_7527_30T_MCI_225428.nii.gz
#   inflating: __MACOSX/testing/._123_S_2055_ADNIGO_M_7527_30T_MCI_225428.nii.gz
#   inflating: testing/123_S_0108_ADNI1_M_7832_15T_MCI_64416.nii.gz
#   inflating: __MACOSX/testing/._123_S_0108_ADNI1_M_7832_15T_MCI_64416.nii.gz
#   inflating: testing/098_S_2047_ADNIGO_M_7752_30T_MCI_223376.nii.gz
#   inflating: __MACOSX/testing/._098_S_2047_ADNIGO_M_7752_30T_MCI_223376.nii.gz
#   inflating: testing/141_S_1137_ADNI1_F_8163_15T_AD_48580.nii.gz
#   inflating: __MACOSX/testing/._141_S_1137_ADNI1_F_8163_15T_AD_48580.nii.gz
#   inflating: testing/094_S_2216_ADNIGO_M_6822_30T_MCI_223371.nii.gz
#   inflating: __MACOSX/testing/._094_S_2216_ADNIGO_M_6822_30T_MCI_223371.nii.gz
#   inflating: testing/126_S_1187_ADNI1_M_7650_15T_MCI_48958.nii.gz
#   inflating: __MACOSX/testing/._126_S_1187_ADNI1_M_7650_15T_MCI_48958.nii.gz
#   inflating: testing/137_S_1041_ADNI1_M_7097_15T_AD_43070.nii.gz
#   inflating: __MACOSX/testing/._137_S_1041_ADNI1_M_7097_15T_AD_43070.nii.gz
#   inflating: testing/023_S_4448_ADNI2_F_6385_30T_HC_281431.nii.gz
#   inflating: __MACOSX/testing/._023_S_4448_ADNI2_F_6385_30T_HC_281431.nii.gz
#   inflating: testing/029_S_0845_ADNI1_M_8036_15T_HC_64866.nii.gz
#   inflating: __MACOSX/testing/._029_S_0845_ADNI1_M_8036_15T_HC_64866.nii.gz
#   inflating: testing/099_S_4463_ADNI2_M_6661_30T_MCI_283954.nii.gz
#   inflating: __MACOSX/testing/._099_S_4463_ADNI2_M_6661_30T_MCI_283954.nii.gz
#   inflating: testing/116_S_1083_ADNI1_F_7211_29T_AD_67247.nii.gz
#   inflating: __MACOSX/testing/._116_S_1083_ADNI1_F_7211_29T_AD_67247.nii.gz
#   inflating: testing/133_S_0771_ADNI1_F_7442_29T_MCI_51093.nii.gz
#   inflating: __MACOSX/testing/._133_S_0771_ADNI1_F_7442_29T_MCI_51093.nii.gz
#   inflating: testing/041_S_1418_ADNI1_M_8162_15T_MCI_73641.nii.gz
#   inflating: __MACOSX/testing/._041_S_1418_ADNI1_M_8162_15T_MCI_73641.nii.gz
#   inflating: testing/116_S_1315_ADNI1_F_8342_15T_MCI_59717.nii.gz
#   inflating: __MACOSX/testing/._116_S_1315_ADNI1_F_8342_15T_MCI_59717.nii.gz
#   inflating: testing/082_S_0363_ADNI1_F_7169_15T_HC_39729.nii.gz
#   inflating: __MACOSX/testing/._082_S_0363_ADNI1_F_7169_15T_HC_39729.nii.gz
#   inflating: testing/068_S_4217_ADNI2_M_7647_30T_MCI_255437.nii.gz
#   inflating: __MACOSX/testing/._068_S_4217_ADNI2_M_7647_30T_MCI_255437.nii.gz
#   inflating: testing/007_S_1222_ADNI1_F_7350_30T_HC_59985.nii.gz
#   inflating: __MACOSX/testing/._007_S_1222_ADNI1_F_7350_30T_HC_59985.nii.gz
#   inflating: testing/051_S_1040_ADNI1_M_7152_15T_MCI_58037.nii.gz
#   inflating: __MACOSX/testing/._051_S_1040_ADNI1_M_7152_15T_MCI_58037.nii.gz
#   inflating: testing/094_S_1293_ADNI1_M_7725_30T_MCI_87747.nii.gz
#   inflating: __MACOSX/testing/._094_S_1293_ADNI1_M_7725_30T_MCI_87747.nii.gz
#   inflating: testing/153_S_4172_ADNI2_M_7593_30T_AD_254771.nii.gz
#   inflating: __MACOSX/testing/._153_S_4172_ADNI2_M_7593_30T_AD_254771.nii.gz
#   inflating: testing/129_S_4369_ADNI2_M_6840_30T_HC_267779.nii.gz
#   inflating: __MACOSX/testing/._129_S_4369_ADNI2_M_6840_30T_HC_267779.nii.gz
#   inflating: testing/023_S_0916_ADNI1_M_7980_30T_AD_31539.nii.gz
#   inflating: __MACOSX/testing/._023_S_0916_ADNI1_M_7980_30T_AD_31539.nii.gz
#   inflating: testing/128_S_0135_ADNI1_F_8238_15T_MCI_68622.nii.gz
#   inflating: __MACOSX/testing/._128_S_0135_ADNI1_F_8238_15T_MCI_68622.nii.gz
#   inflating: testing/129_S_2347_ADNIGO_M_7115_30T_MCI_312705.nii.gz
#   inflating: __MACOSX/testing/._129_S_2347_ADNIGO_M_7115_30T_MCI_312705.nii.gz
#   inflating: testing/099_S_2146_ADNIGO_M_6648_30T_MCI_223459.nii.gz
#   inflating: __MACOSX/testing/._099_S_2146_ADNIGO_M_6648_30T_MCI_223459.nii.gz
#   inflating: testing/057_S_1379_ADNI1_M_8787_15T_AD_63013.nii.gz
#   inflating: __MACOSX/testing/._057_S_1379_ADNI1_M_8787_15T_AD_63013.nii.gz
#   inflating: testing/153_S_4372_ADNI2_F_7014_30T_HC_270067.nii.gz
#   inflating: __MACOSX/testing/._153_S_4372_ADNI2_F_7014_30T_HC_270067.nii.gz
#   inflating: testing/082_S_0640_ADNI1_F_7307_29T_HC_39771.nii.gz
#   inflating: __MACOSX/testing/._082_S_0640_ADNI1_F_7307_29T_HC_39771.nii.gz
#   inflating: testing/023_S_0058_ADNI1_M_7024_29T_HC_30967.nii.gz
#   inflating: __MACOSX/testing/._023_S_0058_ADNI1_M_7024_29T_HC_30967.nii.gz
#   inflating: testing/068_S_2316_ADNIGO_F_7449_30T_MCI_225403.nii.gz
#   inflating: __MACOSX/testing/._068_S_2316_ADNIGO_F_7449_30T_MCI_225403.nii.gz
#   inflating: testing/082_S_2099_ADNIGO_F_8386_30T_MCI_223358.nii.gz
#   inflating: __MACOSX/testing/._082_S_2099_ADNIGO_F_8386_30T_MCI_223358.nii.gz
#   inflating: testing/013_S_1035_ADNI1_M_8740_29T_HC_51477.nii.gz
#   inflating: __MACOSX/testing/._013_S_1035_ADNI1_M_8740_29T_HC_51477.nii.gz
#   inflating: testing/130_S_4817_ADNI2_M_6075_30T_MCI_322952.nii.gz
#   inflating: __MACOSX/testing/._130_S_4817_ADNI2_M_6075_30T_MCI_322952.nii.gz
#   inflating: testing/114_S_2392_ADNIGO_F_6451_30T_MCI_242885.nii.gz
#   inflating: __MACOSX/testing/._114_S_2392_ADNIGO_F_6451_30T_MCI_242885.nii.gz
#   inflating: testing/094_S_1402_ADNI1_M_6942_15T_AD_66077.nii.gz
#   inflating: __MACOSX/testing/._094_S_1402_ADNI1_M_6942_15T_AD_66077.nii.gz
#   inflating: testing/006_S_4449_ADNI2_F_6700_30T_HC_280571.nii.gz
#   inflating: __MACOSX/testing/._006_S_4449_ADNI2_F_6700_30T_HC_280571.nii.gz
#   inflating: testing/005_S_0223_ADNI1_F_7807_15T_HC_32856.nii.gz
#   inflating: __MACOSX/testing/._005_S_0223_ADNI1_F_7807_15T_HC_32856.nii.gz
#   inflating: testing/023_S_0084_ADNI1_F_7545_15T_AD_31204.nii.gz
#   inflating: __MACOSX/testing/._023_S_0084_ADNI1_F_7545_15T_AD_31204.nii.gz
#   inflating: testing/011_S_4222_ADNI2_F_8238_30T_HC_258684.nii.gz
#   inflating: __MACOSX/testing/._011_S_4222_ADNI2_F_8238_30T_HC_258684.nii.gz
#   inflating: testing/136_S_0579_ADNI1_F_6550_15T_MCI_40409.nii.gz
#   inflating: __MACOSX/testing/._136_S_0579_ADNI1_F_6550_15T_MCI_40409.nii.gz
#   inflating: testing/141_S_1094_ADNI1_M_7605_15T_HC_47731.nii.gz
#   inflating: __MACOSX/testing/._141_S_1094_ADNI1_M_7605_15T_HC_47731.nii.gz
#   inflating: testing/011_S_0008_ADNI1_F_8455_15T_HC_32254.nii.gz
#   inflating: __MACOSX/testing/._011_S_0008_ADNI1_F_8455_15T_HC_32254.nii.gz
#   inflating: testing/153_S_2148_ADNIGO_F_6786_30T_MCI_223535.nii.gz
#   inflating: __MACOSX/testing/._153_S_2148_ADNIGO_F_6786_30T_MCI_223535.nii.gz
#   inflating: testing/027_S_0835_ADNI1_M_7288_29T_MCI_35652.nii.gz
#   inflating: __MACOSX/testing/._027_S_0835_ADNI1_M_7288_29T_MCI_35652.nii.gz
#   inflating: testing/153_S_2109_ADNIGO_M_7532_30T_MCI_223530.nii.gz
#   inflating: __MACOSX/testing/._153_S_2109_ADNIGO_M_7532_30T_MCI_223530.nii.gz
#   inflating: testing/128_S_4774_ADNI2_M_8590_30T_AD_312864.nii.gz
#   inflating: __MACOSX/testing/._128_S_4774_ADNI2_M_8590_30T_AD_312864.nii.gz
#   inflating: testing/022_S_1366_ADNI1_M_7378_15T_MCI_67164.nii.gz
#   inflating: __MACOSX/testing/._022_S_1366_ADNI1_M_7378_15T_MCI_67164.nii.gz
#   inflating: testing/013_S_1205_ADNI1_M_8312_15T_AD_51541.nii.gz
#   inflating: __MACOSX/testing/._013_S_1205_ADNI1_M_8312_15T_AD_51541.nii.gz
#   inflating: testing/057_S_0779_ADNI1_M_7958_15T_HC_80628.nii.gz
#   inflating: __MACOSX/testing/._057_S_0779_ADNI1_M_7958_15T_HC_80628.nii.gz
#   inflating: testing/109_S_0950_ADNI1_M_7362_15T_MCI_97199.nii.gz
#   inflating: __MACOSX/testing/._109_S_0950_ADNI1_M_7362_15T_MCI_97199.nii.gz
#   inflating: testing/037_S_4028_ADNI2_F_6352_30T_HC_229326.nii.gz
#   inflating: __MACOSX/testing/._037_S_4028_ADNI2_F_6352_30T_HC_229326.nii.gz
#   inflating: testing/128_S_2123_ADNIGO_F_6401_30T_MCI_223520.nii.gz
#   inflating: __MACOSX/testing/._128_S_2123_ADNIGO_F_6401_30T_MCI_223520.nii.gz
#   inflating: testing/128_S_1430_ADNI1_F_8355_15T_AD_79856.nii.gz
#   inflating: __MACOSX/testing/._128_S_1430_ADNI1_F_8355_15T_AD_79856.nii.gz
#   inflating: testing/116_S_0657_ADNI1_F_7784_15T_HC_59738.nii.gz
#   inflating: __MACOSX/testing/._116_S_0657_ADNI1_F_7784_15T_HC_59738.nii.gz
#   inflating: testing/072_S_2027_ADNIGO_F_6201_30T_MCI_223240.nii.gz
#   inflating: __MACOSX/testing/._072_S_2027_ADNIGO_F_6201_30T_MCI_223240.nii.gz
#   inflating: testing/130_S_4417_ADNI2_M_7453_30T_MCI_280572.nii.gz
#   inflating: __MACOSX/testing/._130_S_4417_ADNI2_M_7453_30T_MCI_280572.nii.gz
#   inflating: testing/057_S_0839_ADNI1_F_7953_15T_MCI_38669.nii.gz
#   inflating: __MACOSX/testing/._057_S_0839_ADNI1_F_7953_15T_MCI_38669.nii.gz
#   inflating: testing/116_S_1232_ADNI1_F_7227_29T_HC_53835.nii.gz
#   inflating: __MACOSX/testing/._116_S_1232_ADNI1_F_7227_29T_HC_53835.nii.gz
#   inflating: testing/127_S_5028_ADNI2_M_6194_30T_AD_349916.nii.gz
#   inflating: __MACOSX/testing/._127_S_5028_ADNI2_M_6194_30T_AD_349916.nii.gz
#   inflating: testing/027_S_1082_ADNI1_F_6964_29T_AD_47185.nii.gz
#   inflating: __MACOSX/testing/._027_S_1082_ADNI1_F_6964_29T_AD_47185.nii.gz
#   inflating: testing/067_S_0038_ADNI1_M_7687_15T_MCI_35874.nii.gz
#   inflating: __MACOSX/testing/._067_S_0038_ADNI1_M_7687_15T_MCI_35874.nii.gz
#   inflating: testing/036_S_2380_ADNIGO_M_6796_30T_MCI_241349.nii.gz
#   inflating: __MACOSX/testing/._036_S_2380_ADNIGO_M_6796_30T_MCI_241349.nii.gz
#   inflating: testing/007_S_4516_ADNI2_M_7144_30T_HC_285471.nii.gz
#   inflating: __MACOSX/testing/._007_S_4516_ADNI2_M_7144_30T_HC_285471.nii.gz
#   inflating: testing/136_S_0194_ADNI1_F_8055_15T_AD_40238.nii.gz
#   inflating: __MACOSX/testing/._136_S_0194_ADNI1_F_8055_15T_AD_40238.nii.gz
#   inflating: testing/072_S_2093_ADNIGO_F_5965_30T_MCI_223268.nii.gz
#   inflating: __MACOSX/testing/._072_S_2093_ADNIGO_F_5965_30T_MCI_223268.nii.gz
#   inflating: testing/130_S_4605_ADNI2_F_8478_30T_MCI_294875.nii.gz
#   inflating: __MACOSX/testing/._130_S_4605_ADNI2_F_8478_30T_MCI_294875.nii.gz
#   inflating: testing/126_S_0680_ADNI1_M_7786_15T_HC_38921.nii.gz
#   inflating: __MACOSX/testing/._126_S_0680_ADNI1_M_7786_15T_HC_38921.nii.gz
#   inflating: testing/116_S_4483_ADNI2_F_6962_30T_HC_281416.nii.gz
#   inflating: __MACOSX/testing/._116_S_4483_ADNI2_F_6962_30T_HC_281416.nii.gz
#   inflating: testing/023_S_4020_ADNI2_M_6663_30T_HC_233461.nii.gz
#   inflating: __MACOSX/testing/._023_S_4020_ADNI2_M_6663_30T_HC_233461.nii.gz
#   inflating: testing/135_S_4723_ADNI2_F_6948_30T_MCI_305621.nii.gz
#   inflating: __MACOSX/testing/._135_S_4723_ADNI2_F_6948_30T_MCI_305621.nii.gz
#   inflating: testing/136_S_0300_ADNI1_M_5648_15T_AD_40327.nii.gz
#   inflating: __MACOSX/testing/._136_S_0300_ADNI1_M_5648_15T_AD_40327.nii.gz
#   inflating: testing/127_S_0259_ADNI1_M_7064_15T_HC_34361.nii.gz
#   inflating: __MACOSX/testing/._127_S_0259_ADNI1_M_7064_15T_HC_34361.nii.gz
#   inflating: testing/098_S_0269_ADNI1_M_6720_15T_MCI_65256.nii.gz
#   inflating: __MACOSX/testing/._098_S_0269_ADNI1_M_6720_15T_MCI_65256.nii.gz
#   inflating: testing/137_S_1426_ADNI1_M_8355_15T_MCI_79101.nii.gz
#   inflating: __MACOSX/testing/._137_S_1426_ADNI1_M_8355_15T_MCI_79101.nii.gz
#   inflating: testing/123_S_0088_ADNI1_M_6575_15T_AD_64399.nii.gz
#   inflating: __MACOSX/testing/._123_S_0088_ADNI1_M_6575_15T_AD_64399.nii.gz
#   inflating: testing/128_S_1043_ADNI1_M_6861_15T_MCI_69090.nii.gz
#   inflating: __MACOSX/testing/._128_S_1043_ADNI1_M_6861_15T_MCI_69090.nii.gz
#   inflating: testing/941_S_4420_ADNI2_M_8150_30T_MCI_294867.nii.gz
#   inflating: __MACOSX/testing/._941_S_4420_ADNI2_M_8150_30T_MCI_294867.nii.gz
#   inflating: testing/033_S_5017_ADNI2_M_8438_30T_AD_349897.nii.gz
#   inflating: __MACOSX/testing/._033_S_5017_ADNI2_M_8438_30T_AD_349897.nii.gz
#    creating: training/
#   inflating: __MACOSX/._training
#   inflating: training/127_S_1032_ADNI1_M_8482_15T_MCI_63631.nii.gz
#   inflating: __MACOSX/training/._127_S_1032_ADNI1_M_8482_15T_MCI_63631.nii.gz
#   inflating: training/068_S_2187_ADNIGO_F_5782_30T_MCI_223070.nii.gz
#   inflating: __MACOSX/training/._068_S_2187_ADNIGO_F_5782_30T_MCI_223070.nii.gz
#   inflating: training/024_S_2239_ADNIGO_F_7364_30T_MCI_222916.nii.gz
#   inflating: __MACOSX/training/._024_S_2239_ADNIGO_F_7364_30T_MCI_222916.nii.gz
#   inflating: training/016_S_0359_ADNI1_F_8137_15T_HC_96220.nii.gz
#   inflating: __MACOSX/training/._016_S_0359_ADNI1_F_8137_15T_HC_96220.nii.gz
#   inflating: training/131_S_0409_ADNI1_M_7924_15T_MCI_48010.nii.gz
#   inflating: __MACOSX/training/._131_S_0409_ADNI1_M_7924_15T_MCI_48010.nii.gz
#   inflating: training/135_S_4598_ADNI2_F_6513_30T_HC_291884.nii.gz
#   inflating: __MACOSX/training/._135_S_4598_ADNI2_F_6513_30T_HC_291884.nii.gz
#   inflating: training/018_S_4257_ADNI2_M_7902_30T_HC_263738.nii.gz
#   inflating: __MACOSX/training/._018_S_4257_ADNI2_M_7902_30T_HC_263738.nii.gz
#   inflating: training/137_S_0841_ADNI1_F_7711_15T_AD_49775.nii.gz
#   inflating: __MACOSX/training/._137_S_0841_ADNI1_F_7711_15T_AD_49775.nii.gz
#   inflating: training/041_S_4874_ADNI2_F_5776_30T_MCI_322301.nii.gz
#   inflating: __MACOSX/training/._041_S_4874_ADNI2_F_5776_30T_MCI_322301.nii.gz
#   inflating: training/022_S_4320_ADNI2_F_7081_30T_HC_283918.nii.gz
#   inflating: __MACOSX/training/._022_S_4320_ADNI2_F_7081_30T_HC_283918.nii.gz
#   inflating: training/073_S_2191_ADNIGO_F_6690_30T_MCI_223297.nii.gz
#   inflating: __MACOSX/training/._073_S_2191_ADNIGO_F_6690_30T_MCI_223297.nii.gz
#   inflating: training/099_S_4498_ADNI2_F_7765_30T_MCI_291052.nii.gz
#   inflating: __MACOSX/training/._099_S_4498_ADNI2_F_7765_30T_MCI_291052.nii.gz
#   inflating: training/067_S_0243_ADNI1_F_6810_15T_MCI_34818.nii.gz
#   inflating: __MACOSX/training/._067_S_0243_ADNI1_F_6810_15T_MCI_34818.nii.gz
#   inflating: training/027_S_1254_ADNI1_M_8441_15T_AD_47227.nii.gz
#   inflating: __MACOSX/training/._027_S_1254_ADNI1_M_8441_15T_AD_47227.nii.gz
#   inflating: training/141_S_4711_ADNI2_F_7498_30T_MCI_305539.nii.gz
#   inflating: __MACOSX/training/._141_S_4711_ADNI2_F_7498_30T_MCI_305539.nii.gz
#   inflating: training/033_S_0723_ADNI1_M_7915_15T_MCI_42383.nii.gz
#   inflating: __MACOSX/training/._033_S_0723_ADNI1_M_7915_15T_MCI_42383.nii.gz
#   inflating: training/003_S_4136_ADNI2_M_6676_30T_AD_250665.nii.gz
#   inflating: __MACOSX/training/._003_S_4136_ADNI2_M_6676_30T_AD_250665.nii.gz
#   inflating: training/130_S_0886_ADNI1_F_7137_15T_HC_39172.nii.gz
#   inflating: __MACOSX/training/._130_S_0886_ADNI1_F_7137_15T_HC_39172.nii.gz
#   inflating: training/099_S_0352_ADNI1_F_7714_15T_HC_34536.nii.gz
#   inflating: __MACOSX/training/._099_S_0352_ADNI1_F_7714_15T_HC_34536.nii.gz
#   inflating: training/011_S_0022_ADNI1_M_6328_15T_HC_32388.nii.gz
#   inflating: __MACOSX/training/._011_S_0022_ADNI1_M_6328_15T_HC_32388.nii.gz
#   inflating: training/130_S_4641_ADNI2_F_7365_30T_AD_296409.nii.gz
#   inflating: __MACOSX/training/._130_S_4641_ADNI2_F_7365_30T_AD_296409.nii.gz
#   inflating: training/011_S_0010_ADNI1_F_7397_15T_AD_32269.nii.gz
#   inflating: __MACOSX/training/._011_S_0010_ADNI1_F_7397_15T_AD_32269.nii.gz
#   inflating: training/052_S_4626_ADNI2_M_6930_30T_MCI_296423.nii.gz
#   inflating: __MACOSX/training/._052_S_4626_ADNI2_M_6930_30T_MCI_296423.nii.gz
#   inflating: training/130_S_4660_ADNI2_F_7730_30T_AD_300303.nii.gz
#   inflating: __MACOSX/training/._130_S_4660_ADNI2_F_7730_30T_AD_300303.nii.gz
#   inflating: training/128_S_0863_ADNI1_M_7926_15T_HC_98874.nii.gz
#   inflating: __MACOSX/training/._128_S_0863_ADNI1_M_7926_15T_HC_98874.nii.gz
#   inflating: training/127_S_4210_ADNI2_M_6399_30T_MCI_255431.nii.gz
#   inflating: __MACOSX/training/._127_S_4210_ADNI2_M_6399_30T_MCI_255431.nii.gz
#   inflating: training/053_S_0919_ADNI1_M_6246_15T_MCI_65688.nii.gz
#   inflating: __MACOSX/training/._053_S_0919_ADNI1_M_6246_15T_MCI_65688.nii.gz
#   inflating: training/126_S_1221_ADNI1_M_7127_15T_AD_48975.nii.gz
#   inflating: __MACOSX/training/._126_S_1221_ADNI1_M_7127_15T_AD_48975.nii.gz
#   inflating: training/019_S_4293_ADNI2_M_6980_30T_MCI_297294.nii.gz
#   inflating: __MACOSX/training/._019_S_4293_ADNI2_M_6980_30T_MCI_297294.nii.gz
#   inflating: training/094_S_4434_ADNI2_M_6669_30T_MCI_280554.nii.gz
#   inflating: __MACOSX/training/._094_S_4434_ADNI2_M_6669_30T_MCI_280554.nii.gz
#   inflating: training/033_S_0513_ADNI1_M_6895_15T_MCI_42257.nii.gz
#   inflating: __MACOSX/training/._033_S_0513_ADNI1_M_6895_15T_MCI_42257.nii.gz
#   inflating: training/128_S_0167_ADNI1_M_7648_15T_AD_124935.nii.gz
#   inflating: __MACOSX/training/._128_S_0167_ADNI1_M_7648_15T_AD_124935.nii.gz
#   inflating: training/128_S_0266_ADNI1_M_8559_15T_AD_68897.nii.gz
#   inflating: __MACOSX/training/._128_S_0266_ADNI1_M_8559_15T_AD_68897.nii.gz
#   inflating: training/129_S_1246_ADNI1_M_7248_15T_MCI_69732.nii.gz
#   inflating: __MACOSX/training/._129_S_1246_ADNI1_M_7248_15T_MCI_69732.nii.gz
#   inflating: training/072_S_2083_ADNIGO_F_8843_30T_MCI_223264.nii.gz
#   inflating: __MACOSX/training/._072_S_2083_ADNIGO_F_8843_30T_MCI_223264.nii.gz
#   inflating: training/114_S_0458_ADNI1_F_8304_15T_MCI_39844.nii.gz
#   inflating: __MACOSX/training/._114_S_0458_ADNI1_F_8304_15T_MCI_39844.nii.gz
#   inflating: training/137_S_0668_ADNI1_M_7352_15T_MCI_42999.nii.gz
#   inflating: __MACOSX/training/._137_S_0668_ADNI1_M_7352_15T_MCI_42999.nii.gz
#   inflating: training/013_S_0502_ADNI1_M_7514_15T_HC_51137.nii.gz
#   inflating: __MACOSX/training/._013_S_0502_ADNI1_M_7514_15T_HC_51137.nii.gz
#   inflating: training/027_S_2245_ADNIGO_F_5707_30T_MCI_222936.nii.gz
#   inflating: __MACOSX/training/._027_S_2245_ADNIGO_F_5707_30T_MCI_222936.nii.gz
#   inflating: training/116_S_0370_ADNI1_F_7462_15T_AD_59776.nii.gz
#   inflating: __MACOSX/training/._116_S_0370_ADNI1_F_7462_15T_AD_59776.nii.gz
#   inflating: training/041_S_4143_ADNI2_F_6370_30T_MCI_248677.nii.gz
#   inflating: __MACOSX/training/._041_S_4143_ADNI2_F_6370_30T_MCI_248677.nii.gz
#   inflating: training/032_S_1169_ADNI1_F_7235_30T_HC_90988.nii.gz
#   inflating: __MACOSX/training/._032_S_1169_ADNI1_F_7235_30T_HC_90988.nii.gz
#   inflating: training/141_S_1052_ADNI1_F_6908_15T_MCI_47721.nii.gz
#   inflating: __MACOSX/training/._141_S_1052_ADNI1_F_6908_15T_MCI_47721.nii.gz
#   inflating: training/005_S_0929_ADNI1_M_8211_15T_AD_74608.nii.gz
#   inflating: __MACOSX/training/._005_S_0929_ADNI1_M_8211_15T_AD_74608.nii.gz
#   inflating: training/070_S_4719_ADNI2_F_7918_30T_AD_306757.nii.gz
#   inflating: __MACOSX/training/._070_S_4719_ADNI2_F_7918_30T_AD_306757.nii.gz
#   inflating: training/073_S_4216_ADNI2_M_5642_30T_MCI_254823.nii.gz
#   inflating: __MACOSX/training/._073_S_4216_ADNI2_M_5642_30T_MCI_254823.nii.gz
#   inflating: training/116_S_4043_ADNI2_M_8215_30T_HC_236974.nii.gz
#   inflating: __MACOSX/training/._116_S_4043_ADNI2_M_8215_30T_HC_236974.nii.gz
#   inflating: training/062_S_1294_ADNI1_M_7933_15T_MCI_50574.nii.gz
#   inflating: __MACOSX/training/._062_S_1294_ADNI1_M_7933_15T_MCI_50574.nii.gz
#   inflating: training/135_S_4863_ADNI2_M_7008_30T_AD_322958.nii.gz
#   inflating: __MACOSX/training/._135_S_4863_ADNI2_M_7008_30T_AD_322958.nii.gz
#   inflating: training/127_S_1419_ADNI1_M_7799_15T_MCI_73655.nii.gz
#   inflating: __MACOSX/training/._127_S_1419_ADNI1_M_7799_15T_MCI_73655.nii.gz
#   inflating: training/082_S_0928_ADNI1_F_8295_30T_MCI_109532.nii.gz
#   inflating: __MACOSX/training/._082_S_0928_ADNI1_F_8295_30T_MCI_109532.nii.gz
#   inflating: training/135_S_4446_ADNI2_F_6848_30T_HC_280558.nii.gz
#   inflating: __MACOSX/training/._135_S_4446_ADNI2_F_6848_30T_HC_280558.nii.gz
#   inflating: training/123_S_0162_ADNI1_M_7188_15T_AD_64421.nii.gz
#   inflating: __MACOSX/training/._123_S_0162_ADNI1_M_7188_15T_AD_64421.nii.gz
#   inflating: training/128_S_0517_ADNI1_M_8195_15T_AD_68975.nii.gz
#   inflating: __MACOSX/training/._128_S_0517_ADNI1_M_8195_15T_AD_68975.nii.gz
#   inflating: training/131_S_0691_ADNI1_M_6453_30T_AD_91177.nii.gz
#   inflating: __MACOSX/training/._131_S_0691_ADNI1_M_6453_30T_AD_91177.nii.gz
#   inflating: training/130_S_1201_ADNI1_F_7564_15T_AD_63756.nii.gz
#   inflating: __MACOSX/training/._130_S_1201_ADNI1_F_7564_15T_AD_63756.nii.gz
#   inflating: training/037_S_4214_ADNI2_M_7427_30T_MCI_258628.nii.gz
#   inflating: __MACOSX/training/._037_S_4214_ADNI2_M_7427_30T_MCI_258628.nii.gz
#   inflating: training/037_S_0501_ADNI1_M_7812_29T_MCI_79783.nii.gz
#   inflating: __MACOSX/training/._037_S_0501_ADNI1_M_7812_29T_MCI_79783.nii.gz
#   inflating: training/073_S_0565_ADNI1_M_7469_15T_AD_39918.nii.gz
#   inflating: __MACOSX/training/._073_S_0565_ADNI1_M_7469_15T_AD_39918.nii.gz
#   inflating: training/137_S_4596_ADNI2_M_6580_30T_MCI_291882.nii.gz
#   inflating: __MACOSX/training/._137_S_4596_ADNI2_M_6580_30T_MCI_291882.nii.gz
#   inflating: training/033_S_0511_ADNI1_M_5779_15T_MCI_42239.nii.gz
#   inflating: __MACOSX/training/._033_S_0511_ADNI1_M_5779_15T_MCI_42239.nii.gz
#   inflating: training/016_S_4952_ADNI2_F_6939_30T_HC_338584.nii.gz
#   inflating: __MACOSX/training/._016_S_4952_ADNI2_F_6939_30T_HC_338584.nii.gz
#   inflating: training/116_S_4338_ADNI2_M_8060_30T_AD_267741.nii.gz
#   inflating: __MACOSX/training/._116_S_4338_ADNI2_M_8060_30T_AD_267741.nii.gz
#   inflating: training/006_S_0547_ADNI1_M_7600_15T_AD_75278.nii.gz
#   inflating: __MACOSX/training/._006_S_0547_ADNI1_M_7600_15T_AD_75278.nii.gz
#   inflating: training/941_S_4377_ADNI2_F_6949_30T_MCI_275760.nii.gz
#   inflating: __MACOSX/training/._941_S_4377_ADNI2_F_6949_30T_MCI_275760.nii.gz
#   inflating: training/037_S_0627_ADNI1_F_5855_15T_AD_79830.nii.gz
#   inflating: __MACOSX/training/._037_S_0627_ADNI1_F_5855_15T_AD_79830.nii.gz
#   inflating: training/029_S_1318_ADNI1_F_8294_15T_MCI_60759.nii.gz
#   inflating: __MACOSX/training/._029_S_1318_ADNI1_F_8294_15T_MCI_60759.nii.gz
#   inflating: training/129_S_4220_ADNI2_F_7126_30T_MCI_258655.nii.gz
#   inflating: __MACOSX/training/._129_S_4220_ADNI2_F_7126_30T_MCI_258655.nii.gz
#   inflating: training/029_S_2395_ADNIGO_M_7284_30T_MCI_254758.nii.gz
#   inflating: __MACOSX/training/._029_S_2395_ADNIGO_M_7284_30T_MCI_254758.nii.gz
#   inflating: training/036_S_1240_ADNI1_F_6709_15T_MCI_65117.nii.gz
#   inflating: __MACOSX/training/._036_S_1240_ADNI1_F_6709_15T_MCI_65117.nii.gz
#   inflating: training/052_S_4945_ADNI2_M_5655_30T_MCI_349801.nii.gz
#   inflating: __MACOSX/training/._052_S_4945_ADNI2_M_5655_30T_MCI_349801.nii.gz
#   inflating: training/011_S_0023_ADNI1_M_7181_15T_HC_32401.nii.gz
#   inflating: __MACOSX/training/._011_S_0023_ADNI1_M_7181_15T_HC_32401.nii.gz
#   inflating: training/002_S_4262_ADNI2_F_7290_30T_HC_261070.nii.gz
#   inflating: __MACOSX/training/._002_S_4262_ADNI2_F_7290_30T_HC_261070.nii.gz
#   inflating: training/031_S_4024_ADNI2_F_5601_30T_AD_229343.nii.gz
#   inflating: __MACOSX/training/._031_S_4024_ADNI2_F_5601_30T_AD_229343.nii.gz
#   inflating: training/021_S_0424_ADNI1_M_8070_15T_MCI_33643.nii.gz
#   inflating: __MACOSX/training/._021_S_0424_ADNI1_M_8070_15T_MCI_33643.nii.gz
#   inflating: training/027_S_4919_ADNI2_F_7485_30T_MCI_331861.nii.gz
#   inflating: __MACOSX/training/._027_S_4919_ADNI2_F_7485_30T_MCI_331861.nii.gz
#   inflating: training/116_S_4167_ADNI2_F_6959_30T_MCI_258635.nii.gz
#   inflating: __MACOSX/training/._116_S_4167_ADNI2_F_6959_30T_MCI_258635.nii.gz
#   inflating: training/099_S_0372_ADNI1_M_7914_15T_AD_34548.nii.gz
#   inflating: __MACOSX/training/._099_S_0372_ADNI1_M_7914_15T_AD_34548.nii.gz
#   inflating: training/021_S_4718_ADNI2_M_7860_30T_AD_306699.nii.gz
#   inflating: __MACOSX/training/._021_S_4718_ADNI2_M_7860_30T_AD_306699.nii.gz
#   inflating: training/099_S_0880_ADNI1_M_8433_15T_MCI_68580.nii.gz
#   inflating: __MACOSX/training/._099_S_0880_ADNI1_M_8433_15T_MCI_68580.nii.gz
#   inflating: training/062_S_0578_ADNI1_F_7712_15T_HC_50458.nii.gz
#   inflating: __MACOSX/training/._062_S_0578_ADNI1_F_7712_15T_HC_50458.nii.gz
#   inflating: training/133_S_0629_ADNI1_M_7098_29T_MCI_39995.nii.gz
#   inflating: __MACOSX/training/._133_S_0629_ADNI1_M_7098_29T_MCI_39995.nii.gz
#   inflating: training/024_S_4280_ADNI2_M_7975_30T_AD_263677.nii.gz
#   inflating: __MACOSX/training/._024_S_4280_ADNI2_M_7975_30T_AD_263677.nii.gz
#   inflating: training/036_S_0748_ADNI1_M_7964_15T_MCI_36958.nii.gz
#   inflating: __MACOSX/training/._036_S_0748_ADNI1_M_7964_15T_MCI_36958.nii.gz
#   inflating: training/023_S_4034_ADNI2_F_7225_30T_MCI_241370.nii.gz
#   inflating: __MACOSX/training/._023_S_4034_ADNI2_F_7225_30T_MCI_241370.nii.gz
#   inflating: training/099_S_0291_ADNI1_M_7943_15T_MCI_34523.nii.gz
#   inflating: __MACOSX/training/._099_S_0291_ADNI1_M_7943_15T_MCI_34523.nii.gz
#   inflating: training/057_S_1265_ADNI1_F_8224_15T_MCI_69491.nii.gz
#   inflating: __MACOSX/training/._057_S_1265_ADNI1_F_8224_15T_MCI_69491.nii.gz
#   inflating: training/027_S_0256_ADNI1_M_7021_15T_MCI_34149.nii.gz
#   inflating: __MACOSX/training/._027_S_0256_ADNI1_M_7021_15T_MCI_34149.nii.gz
#   inflating: training/021_S_0647_ADNI1_M_7293_15T_HC_33458.nii.gz
#   inflating: __MACOSX/training/._021_S_0647_ADNI1_M_7293_15T_HC_33458.nii.gz
#   inflating: training/019_S_4835_ADNI2_M_7939_30T_HC_321304.nii.gz
#   inflating: __MACOSX/training/._019_S_4835_ADNI2_M_7939_30T_HC_321304.nii.gz
#   inflating: training/094_S_4503_ADNI2_F_7182_30T_HC_288886.nii.gz
#   inflating: __MACOSX/training/._094_S_4503_ADNI2_F_7182_30T_HC_288886.nii.gz
#   inflating: training/130_S_0969_ADNI1_M_7009_15T_HC_39276.nii.gz
#   inflating: __MACOSX/training/._130_S_0969_ADNI1_M_7009_15T_HC_39276.nii.gz
#   inflating: training/128_S_4553_ADNI2_F_6859_30T_MCI_286635.nii.gz
#   inflating: __MACOSX/training/._128_S_4553_ADNI2_F_6859_30T_MCI_286635.nii.gz
#   inflating: training/072_S_2070_ADNIGO_F_5714_30T_MCI_223256.nii.gz
#   inflating: __MACOSX/training/._072_S_2070_ADNIGO_F_5714_30T_MCI_223256.nii.gz
#   inflating: training/133_S_0638_ADNI1_M_8343_29T_MCI_70908.nii.gz
#   inflating: __MACOSX/training/._133_S_0638_ADNI1_M_8343_29T_MCI_70908.nii.gz
#   inflating: training/941_S_4187_ADNI2_M_6185_30T_MCI_258653.nii.gz
#   inflating: __MACOSX/training/._941_S_4187_ADNI2_M_6185_30T_MCI_258653.nii.gz
#   inflating: training/123_S_4362_ADNI2_F_6792_30T_HC_270052.nii.gz
#   inflating: __MACOSX/training/._123_S_4362_ADNI2_F_6792_30T_HC_270052.nii.gz
#   inflating: training/127_S_1210_ADNI1_M_7433_15T_MCI_63645.nii.gz
#   inflating: __MACOSX/training/._127_S_1210_ADNI1_M_7433_15T_MCI_63645.nii.gz
#   inflating: training/037_S_0303_ADNI1_M_8442_29T_HC_64115.nii.gz
#   inflating: __MACOSX/training/._037_S_0303_ADNI1_M_8442_29T_HC_64115.nii.gz
#   inflating: training/024_S_4392_ADNI2_M_8261_30T_MCI_275417.nii.gz
#   inflating: __MACOSX/training/._024_S_4392_ADNI2_M_8261_30T_MCI_275417.nii.gz
#   inflating: training/133_S_0488_ADNI1_F_7105_29T_HC_39968.nii.gz
#   inflating: __MACOSX/training/._133_S_0488_ADNI1_F_7105_29T_HC_39968.nii.gz
#   inflating: training/127_S_0397_ADNI1_M_7481_30T_MCI_34415.nii.gz
#   inflating: __MACOSX/training/._127_S_0397_ADNI1_M_7481_30T_MCI_34415.nii.gz
#   inflating: training/027_S_4966_ADNI2_M_6184_30T_MCI_340506.nii.gz
#   inflating: __MACOSX/training/._027_S_4966_ADNI2_M_6184_30T_MCI_340506.nii.gz
#   inflating: training/082_S_0641_ADNI1_M_7444_15T_MCI_39784.nii.gz
#   inflating: __MACOSX/training/._082_S_0641_ADNI1_M_7444_15T_MCI_39784.nii.gz
#   inflating: training/141_S_0853_ADNI1_M_8683_15T_AD_112291.nii.gz
#   inflating: __MACOSX/training/._141_S_0853_ADNI1_M_8683_15T_AD_112291.nii.gz
#   inflating: training/023_S_1247_ADNI1_F_7261_30T_MCI_52137.nii.gz
#   inflating: __MACOSX/training/._023_S_1247_ADNI1_F_7261_30T_MCI_52137.nii.gz
#   inflating: training/021_S_0276_ADNI1_M_7095_15T_MCI_33434.nii.gz
#   inflating: __MACOSX/training/._021_S_0276_ADNI1_M_7095_15T_MCI_33434.nii.gz
#   inflating: training/127_S_0844_ADNI1_F_8546_30T_AD_83520.nii.gz
#   inflating: __MACOSX/training/._127_S_0844_ADNI1_F_8546_30T_AD_83520.nii.gz
#   inflating: training/002_S_1018_ADNI1_F_7075_15T_AD_40816.nii.gz
#   inflating: __MACOSX/training/._002_S_1018_ADNI1_F_7075_15T_AD_40816.nii.gz
#   inflating: training/003_S_4081_ADNI2_F_7285_30T_HC_244937.nii.gz
#   inflating: __MACOSX/training/._003_S_4081_ADNI2_F_7285_30T_HC_244937.nii.gz
#   inflating: training/006_S_4485_ADNI2_M_7337_30T_HC_283928.nii.gz
#   inflating: __MACOSX/training/._006_S_4485_ADNI2_M_7337_30T_HC_283928.nii.gz
#   inflating: training/941_S_4764_ADNI2_F_8280_30T_MCI_312638.nii.gz
#   inflating: __MACOSX/training/._941_S_4764_ADNI2_F_8280_30T_MCI_312638.nii.gz
#   inflating: training/033_S_0724_ADNI1_M_7870_29T_AD_42392.nii.gz
#   inflating: __MACOSX/training/._033_S_0724_ADNI1_M_7870_29T_AD_42392.nii.gz
#   inflating: training/072_S_4871_ADNI2_F_6655_30T_MCI_326503.nii.gz
#   inflating: __MACOSX/training/._072_S_4871_ADNI2_F_6655_30T_MCI_326503.nii.gz
#   inflating: training/067_S_0029_ADNI1_M_6421_15T_AD_38716.nii.gz
#   inflating: __MACOSX/training/._067_S_0029_ADNI1_M_6421_15T_AD_38716.nii.gz
#   inflating: training/130_S_4294_ADNI2_F_7542_30T_MCI_270027.nii.gz
#   inflating: __MACOSX/training/._130_S_4294_ADNI2_F_7542_30T_MCI_270027.nii.gz
#   inflating: training/029_S_1384_ADNI1_M_7215_15T_MCI_64906.nii.gz
#   inflating: __MACOSX/training/._029_S_1384_ADNI1_M_7215_15T_MCI_64906.nii.gz
#   inflating: training/068_S_4274_ADNI2_M_6310_30T_MCI_261077.nii.gz
#   inflating: __MACOSX/training/._068_S_4274_ADNI2_M_6310_30T_MCI_261077.nii.gz
#   inflating: training/023_S_4241_ADNI2_F_6991_30T_MCI_283936.nii.gz
#   inflating: __MACOSX/training/._023_S_4241_ADNI2_F_6991_30T_MCI_283936.nii.gz
#   inflating: training/135_S_4689_ADNI2_M_6965_30T_MCI_305424.nii.gz
#   inflating: __MACOSX/training/._135_S_4689_ADNI2_M_6965_30T_MCI_305424.nii.gz
#   inflating: training/031_S_2018_ADNIGO_F_7655_30T_MCI_222947.nii.gz
#   inflating: __MACOSX/training/._031_S_2018_ADNIGO_F_7655_30T_MCI_222947.nii.gz
#   inflating: training/116_S_4732_ADNI2_M_7734_30T_AD_312656.nii.gz
#   inflating: __MACOSX/training/._116_S_4732_ADNI2_M_7734_30T_AD_312656.nii.gz
#   inflating: training/037_S_0588_ADNI1_M_6474_15T_MCI_79823.nii.gz
#   inflating: __MACOSX/training/._037_S_0588_ADNI1_M_6474_15T_MCI_79823.nii.gz
#   inflating: training/031_S_2233_ADNIGO_F_5566_30T_MCI_222973.nii.gz
#   inflating: __MACOSX/training/._031_S_2233_ADNIGO_F_5566_30T_MCI_222973.nii.gz
#   inflating: training/141_S_0851_ADNI1_F_7266_15T_MCI_47869.nii.gz
#   inflating: __MACOSX/training/._141_S_0851_ADNI1_F_7266_15T_MCI_47869.nii.gz
#   inflating: training/128_S_0947_ADNI1_F_8268_15T_MCI_69072.nii.gz
#   inflating: __MACOSX/training/._128_S_0947_ADNI1_F_8268_15T_MCI_69072.nii.gz
#   inflating: training/082_S_1119_ADNI1_M_7654_15T_MCI_63145.nii.gz
#   inflating: __MACOSX/training/._082_S_1119_ADNI1_M_7654_15T_MCI_63145.nii.gz
#   inflating: training/068_S_2193_ADNIGO_M_7564_30T_MCI_223073.nii.gz
#   inflating: __MACOSX/training/._068_S_2193_ADNIGO_M_7564_30T_MCI_223073.nii.gz
#   inflating: training/941_S_1203_ADNI1_M_8343_15T_HC_63878.nii.gz
#   inflating: __MACOSX/training/._941_S_1203_ADNI1_M_8343_15T_HC_63878.nii.gz
#   inflating: training/067_S_1185_ADNI1_M_6216_30T_AD_86428.nii.gz
#   inflating: __MACOSX/training/._067_S_1185_ADNI1_M_6216_30T_AD_86428.nii.gz
#   inflating: training/014_S_1095_ADNI1_F_8037_15T_AD_45739.nii.gz
#   inflating: __MACOSX/training/._014_S_1095_ADNI1_F_8037_15T_AD_45739.nii.gz
#   inflating: training/023_S_4164_ADNI2_M_7273_30T_HC_254821.nii.gz
#   inflating: __MACOSX/training/._023_S_4164_ADNI2_M_7273_30T_HC_254821.nii.gz
#   inflating: training/021_S_0159_ADNI1_F_7796_15T_HC_33490.nii.gz
#   inflating: __MACOSX/training/._021_S_0159_ADNI1_F_7796_15T_HC_33490.nii.gz
#   inflating: training/036_S_1135_ADNI1_M_7570_15T_MCI_65108.nii.gz
#   inflating: __MACOSX/training/._036_S_1135_ADNI1_M_7570_15T_MCI_65108.nii.gz
#   inflating: training/023_S_0078_ADNI1_F_7615_29T_AD_51980.nii.gz
#   inflating: __MACOSX/training/._023_S_0078_ADNI1_F_7615_29T_AD_51980.nii.gz
#   inflating: training/072_S_4206_ADNI2_M_6867_30T_MCI_255405.nii.gz
#   inflating: __MACOSX/training/._072_S_4206_ADNI2_M_6867_30T_MCI_255405.nii.gz
#   inflating: training/036_S_0869_ADNI1_F_8303_15T_MCI_36992.nii.gz
#   inflating: __MACOSX/training/._036_S_0869_ADNI1_F_8303_15T_MCI_36992.nii.gz
#   inflating: training/128_S_4636_ADNI2_F_7712_30T_MCI_295862.nii.gz
#   inflating: __MACOSX/training/._128_S_4636_ADNI2_F_7712_30T_MCI_295862.nii.gz
#   inflating: training/003_S_4644_ADNI2_F_6769_30T_HC_300940.nii.gz
#   inflating: __MACOSX/training/._003_S_4644_ADNI2_F_6769_30T_HC_300940.nii.gz
#   inflating: training/035_S_2061_ADNIGO_F_6616_30T_MCI_223013.nii.gz
#   inflating: __MACOSX/training/._035_S_2061_ADNIGO_F_6616_30T_MCI_223013.nii.gz
#   inflating: training/135_S_4657_ADNI2_F_7161_30T_AD_297889.nii.gz
#   inflating: __MACOSX/training/._135_S_4657_ADNI2_F_7161_30T_AD_297889.nii.gz
#   inflating: training/141_S_0915_ADNI1_F_8085_15T_MCI_48562.nii.gz
#   inflating: __MACOSX/training/._141_S_0915_ADNI1_F_8085_15T_MCI_48562.nii.gz
#   inflating: training/127_S_4843_ADNI2_F_7344_30T_HC_322917.nii.gz
#   inflating: __MACOSX/training/._127_S_4843_ADNI2_F_7344_30T_HC_322917.nii.gz
#   inflating: training/036_S_0576_ADNI1_M_7757_15T_HC_36899.nii.gz
#   inflating: __MACOSX/training/._036_S_0576_ADNI1_M_7757_15T_HC_36899.nii.gz
#   inflating: training/041_S_4876_ADNI2_M_7432_30T_MCI_326580.nii.gz
#   inflating: __MACOSX/training/._041_S_4876_ADNI2_M_7432_30T_MCI_326580.nii.gz
#   inflating: training/005_S_0221_ADNI1_M_6753_15T_AD_72127.nii.gz
#   inflating: __MACOSX/training/._005_S_0221_ADNI1_M_6753_15T_AD_72127.nii.gz
#   inflating: training/003_S_0931_ADNI1_F_8624_15T_HC_53389.nii.gz
#   inflating: __MACOSX/training/._003_S_0931_ADNI1_F_8624_15T_HC_53389.nii.gz
#   inflating: training/098_S_4275_ADNI2_M_7285_30T_HC_265252.nii.gz
#   inflating: __MACOSX/training/._098_S_4275_ADNI2_M_7285_30T_HC_265252.nii.gz
#   inflating: training/116_S_0382_ADNI1_F_7570_29T_HC_53801.nii.gz
#   inflating: __MACOSX/training/._116_S_0382_ADNI1_F_7570_29T_HC_53801.nii.gz
#   inflating: training/029_S_1056_ADNI1_F_7122_15T_AD_60740.nii.gz
#   inflating: __MACOSX/training/._029_S_1056_ADNI1_F_7122_15T_AD_60740.nii.gz
#   inflating: training/099_S_2205_ADNIGO_M_8488_30T_MCI_223463.nii.gz
#   inflating: __MACOSX/training/._099_S_2205_ADNIGO_M_8488_30T_MCI_223463.nii.gz
#   inflating: training/098_S_0884_ADNI1_M_7907_15T_AD_56025.nii.gz
#   inflating: __MACOSX/training/._098_S_0884_ADNI1_M_7907_15T_AD_56025.nii.gz
#   inflating: training/137_S_4331_ADNI2_F_7544_30T_MCI_267778.nii.gz
#   inflating: __MACOSX/training/._137_S_4331_ADNI2_F_7544_30T_MCI_267778.nii.gz
#   inflating: training/023_S_0030_ADNI1_F_8008_29T_MCI_31622.nii.gz
#   inflating: __MACOSX/training/._023_S_0030_ADNI1_F_8008_29T_MCI_31622.nii.gz
#   inflating: training/002_S_1261_ADNI1_F_7120_15T_HC_62376.nii.gz
#   inflating: __MACOSX/training/._002_S_1261_ADNI1_F_7120_15T_HC_62376.nii.gz
#   inflating: training/126_S_4686_ADNI2_M_7177_30T_AD_305421.nii.gz
#   inflating: __MACOSX/training/._126_S_4686_ADNI2_M_7177_30T_AD_305421.nii.gz
#   inflating: training/129_S_4396_ADNI2_F_7847_30T_HC_270065.nii.gz
#   inflating: __MACOSX/training/._129_S_4396_ADNI2_F_7847_30T_HC_270065.nii.gz
#   inflating: training/128_S_0272_ADNI1_F_7052_15T_HC_68925.nii.gz
#   inflating: __MACOSX/training/._128_S_0272_ADNI1_F_7052_15T_HC_68925.nii.gz
#   inflating: training/027_S_0307_ADNI1_M_7871_29T_MCI_34167.nii.gz
#   inflating: __MACOSX/training/._027_S_0307_ADNI1_M_7871_29T_MCI_34167.nii.gz
#   inflating: training/027_S_4955_ADNI2_M_7148_30T_MCI_339189.nii.gz
#   inflating: __MACOSX/training/._027_S_4955_ADNI2_M_7148_30T_MCI_339189.nii.gz
#   inflating: training/099_S_0111_ADNI1_F_7589_15T_MCI_35848.nii.gz
#   inflating: __MACOSX/training/._099_S_0111_ADNI1_F_7589_15T_MCI_35848.nii.gz
#   inflating: training/072_S_2164_ADNIGO_F_7097_30T_MCI_223280.nii.gz
#   inflating: __MACOSX/training/._072_S_2164_ADNIGO_F_7097_30T_MCI_223280.nii.gz
#   inflating: training/031_S_1066_ADNI1_M_7250_30T_MCI_90915.nii.gz
#   inflating: __MACOSX/training/._031_S_1066_ADNI1_M_7250_30T_MCI_90915.nii.gz
#   inflating: training/137_S_4482_ADNI2_F_7731_30T_HC_285903.nii.gz
#   inflating: __MACOSX/training/._137_S_4482_ADNI2_F_7731_30T_HC_285903.nii.gz
#   inflating: training/068_S_2194_ADNIGO_F_7109_30T_MCI_223075.nii.gz
#   inflating: __MACOSX/training/._068_S_2194_ADNIGO_F_7109_30T_MCI_223075.nii.gz
#   inflating: training/027_S_1387_ADNI1_M_8578_29T_MCI_47756.nii.gz
#   inflating: __MACOSX/training/._027_S_1387_ADNI1_M_8578_29T_MCI_47756.nii.gz
#   inflating: training/023_S_0625_ADNI1_M_7603_30T_MCI_31499.nii.gz
#   inflating: __MACOSX/training/._023_S_0625_ADNI1_M_7603_30T_MCI_31499.nii.gz
#   inflating: training/109_S_1114_ADNI1_F_7847_15T_MCI_63488.nii.gz
#   inflating: __MACOSX/training/._109_S_1114_ADNI1_F_7847_15T_MCI_63488.nii.gz
#   inflating: training/037_S_0377_ADNI1_M_7944_15T_MCI_83093.nii.gz
#   inflating: __MACOSX/training/._037_S_0377_ADNI1_M_7944_15T_MCI_83093.nii.gz
#   inflating: training/128_S_1242_ADNI1_F_7124_29T_HC_94657.nii.gz
#   inflating: __MACOSX/training/._128_S_1242_ADNI1_F_7124_29T_HC_94657.nii.gz
#   inflating: training/023_S_0217_ADNI1_F_8365_15T_MCI_31345.nii.gz
#   inflating: __MACOSX/training/._023_S_0217_ADNI1_F_8365_15T_MCI_31345.nii.gz
#   inflating: training/137_S_0366_ADNI1_F_5665_15T_AD_46607.nii.gz
#   inflating: __MACOSX/training/._137_S_0366_ADNI1_F_5665_15T_AD_46607.nii.gz
#   inflating: training/135_S_4356_ADNI2_M_6816_30T_MCI_267754.nii.gz
#   inflating: __MACOSX/training/._135_S_4356_ADNI2_M_6816_30T_MCI_267754.nii.gz
#   inflating: training/052_S_1346_ADNI1_M_7266_15T_MCI_62298.nii.gz
#   inflating: __MACOSX/training/._052_S_1346_ADNI1_M_7266_15T_MCI_62298.nii.gz
#   inflating: training/123_S_4806_ADNI2_M_5599_30T_MCI_312850.nii.gz
#   inflating: __MACOSX/training/._123_S_4806_ADNI2_M_5599_30T_MCI_312850.nii.gz
#   inflating: training/126_S_0606_ADNI1_F_6867_30T_AD_38886.nii.gz
#   inflating: __MACOSX/training/._126_S_0606_ADNI1_F_6867_30T_AD_38886.nii.gz
#   inflating: training/029_S_0871_ADNI1_M_6869_15T_MCI_60718.nii.gz
#   inflating: __MACOSX/training/._029_S_0871_ADNI1_M_6869_15T_MCI_60718.nii.gz
#   inflating: training/023_S_0081_ADNI1_M_7073_15T_HC_31124.nii.gz
#   inflating: __MACOSX/training/._023_S_0081_ADNI1_M_7073_15T_HC_31124.nii.gz
#   inflating: training/033_S_1285_ADNI1_F_8012_15T_AD_51587.nii.gz
#   inflating: __MACOSX/training/._033_S_1285_ADNI1_F_8012_15T_AD_51587.nii.gz
#   inflating: training/067_S_2195_ADNIGO_M_6810_30T_MCI_223047.nii.gz
#   inflating: __MACOSX/training/._067_S_2195_ADNIGO_M_6810_30T_MCI_223047.nii.gz
#   inflating: training/127_S_0684_ADNI1_F_7749_15T_HC_34457.nii.gz
#   inflating: __MACOSX/training/._127_S_0684_ADNI1_F_7749_15T_HC_34457.nii.gz
#   inflating: training/127_S_0393_ADNI1_F_8635_30T_MCI_38789.nii.gz
#   inflating: __MACOSX/training/._127_S_0393_ADNI1_F_8635_30T_MCI_38789.nii.gz
#   inflating: training/941_S_1194_ADNI1_M_8484_15T_HC_63846.nii.gz
# ...
#   inflating: training/128_S_4609_ADNI2_F_8175_30T_HC_296407.nii.gz
#   inflating: __MACOSX/training/._128_S_4609_ADNI2_F_8175_30T_HC_296407.nii.gz
#   inflating: training/073_S_4155_ADNI2_F_7766_30T_HC_248679.nii.gz
#   inflating: __MACOSX/training/._073_S_4155_ADNI2_F_7766_30T_HC_248679.nii.gz
#   inflating: training/067_S_0336_ADNI1_M_7626_15T_MCI_34856.nii.gz
#   inflating: __MACOSX/training/._067_S_0336_ADNI1_M_7626_15T_MCI_34856.nii.gz
#   inflating: training/023_S_0042_ADNI1_M_7288_15T_MCI_31083.nii.gz
#   inflating: __MACOSX/training/._023_S_0042_ADNI1_M_7288_15T_MCI_31083.nii.gz
#   inflating: training/123_S_0390_ADNI1_M_8051_15T_MCI_64429.nii.gz
#   inflating: __MACOSX/training/._123_S_0390_ADNI1_M_8051_15T_MCI_64429.nii.gz
#   inflating: training/006_S_0484_ADNI1_M_7111_15T_HC_65565.nii.gz
#   inflating: __MACOSX/training/._006_S_0484_ADNI1_M_7111_15T_HC_65565.nii.gz
#   inflating: training/014_S_4401_ADNI2_F_6753_30T_HC_270063.nii.gz
#   inflating: __MACOSX/training/._014_S_4401_ADNI2_F_6753_30T_HC_270063.nii.gz
#   inflating: training/027_S_1277_ADNI1_M_8648_29T_MCI_47236.nii.gz
#   inflating: __MACOSX/training/._027_S_1277_ADNI1_M_8648_29T_MCI_47236.nii.gz
#   inflating: training/073_S_0312_ADNI1_M_8296_15T_HC_39877.nii.gz
#   inflating: __MACOSX/training/._073_S_0312_ADNI1_M_8296_15T_HC_39877.nii.gz
#   inflating: training/018_S_4399_ADNI2_F_7801_30T_HC_272814.nii.gz
#   inflating: __MACOSX/training/._018_S_4399_ADNI2_F_7801_30T_HC_272814.nii.gz
#   inflating: training/022_S_0961_ADNI1_M_7293_15T_MCI_59600.nii.gz
#   inflating: __MACOSX/training/._022_S_0961_ADNI1_M_7293_15T_MCI_59600.nii.gz
#   inflating: training/062_S_0535_ADNI1_M_7684_15T_AD_50425.nii.gz
#   inflating: __MACOSX/training/._062_S_0535_ADNI1_M_7684_15T_AD_50425.nii.gz
#   inflating: training/126_S_4743_ADNI2_M_7015_30T_MCI_306758.nii.gz
#   inflating: __MACOSX/training/._126_S_4743_ADNI2_M_7015_30T_MCI_306758.nii.gz
#   inflating: training/041_S_0549_ADNI1_M_6888_15T_MCI_39494.nii.gz
#   inflating: __MACOSX/training/._041_S_0549_ADNI1_M_6888_15T_MCI_39494.nii.gz
#   inflating: training/067_S_0176_ADNI1_M_7488_15T_MCI_34796.nii.gz
#   inflating: __MACOSX/training/._067_S_0176_ADNI1_M_7488_15T_MCI_34796.nii.gz
#   inflating: training/094_S_0526_ADNI1_F_8517_15T_HC_63467.nii.gz
#   inflating: __MACOSX/training/._094_S_0526_ADNI1_F_8517_15T_HC_63467.nii.gz
#   inflating: training/027_S_0118_ADNI1_M_8057_15T_HC_34113.nii.gz
#   inflating: __MACOSX/training/._027_S_0118_ADNI1_M_8057_15T_HC_34113.nii.gz
#   inflating: training/022_S_4266_ADNI2_F_6997_30T_HC_267771.nii.gz
#   inflating: __MACOSX/training/._022_S_4266_ADNI2_F_6997_30T_HC_267771.nii.gz
#   inflating: training/003_S_4441_ADNI2_F_6877_30T_HC_277674.nii.gz
#   inflating: __MACOSX/training/._003_S_4441_ADNI2_F_6877_30T_HC_277674.nii.gz
#   inflating: training/009_S_1334_ADNI1_M_6433_15T_AD_60433.nii.gz
#   inflating: __MACOSX/training/._009_S_1334_ADNI1_M_6433_15T_AD_60433.nii.gz
#   inflating: training/109_S_4594_ADNI2_M_015_30T_MCI_300258.nii.gz
#   inflating: __MACOSX/training/._109_S_4594_ADNI2_M_015_30T_MCI_300258.nii.gz
#   inflating: training/131_S_0457_ADNI1_F_8293_30T_AD_83834.nii.gz
#   inflating: __MACOSX/training/._131_S_0457_ADNI1_F_8293_30T_AD_83834.nii.gz
#   inflating: training/057_S_1371_ADNI1_M_8435_15T_AD_62997.nii.gz
#   inflating: __MACOSX/training/._057_S_1371_ADNI1_M_8435_15T_AD_62997.nii.gz
#   inflating: training/098_S_4506_ADNI2_M_7162_30T_HC_288878.nii.gz
#   inflating: __MACOSX/training/._098_S_4506_ADNI2_M_7162_30T_HC_288878.nii.gz
#   inflating: training/141_S_0767_ADNI1_F_7313_15T_HC_47305.nii.gz
#   inflating: __MACOSX/training/._141_S_0767_ADNI1_F_7313_15T_HC_47305.nii.gz
#   inflating: training/013_S_1276_ADNI1_F_7200_29T_HC_71394.nii.gz
#   inflating: __MACOSX/training/._013_S_1276_ADNI1_F_7200_29T_HC_71394.nii.gz
#   inflating: training/141_S_4803_ADNI2_F_8276_30T_MCI_312867.nii.gz
#   inflating: __MACOSX/training/._141_S_4803_ADNI2_F_8276_30T_MCI_312867.nii.gz
#   inflating: training/082_S_1256_ADNI1_F_7170_30T_HC_80879.nii.gz
#   inflating: __MACOSX/training/._082_S_1256_ADNI1_F_7170_30T_HC_80879.nii.gz
#   inflating: training/073_S_0089_ADNI1_M_6513_15T_HC_49674.nii.gz
#   inflating: __MACOSX/training/._073_S_0089_ADNI1_M_6513_15T_HC_49674.nii.gz
#   inflating: training/128_S_4586_ADNI2_M_7607_30T_HC_312675.nii.gz
#   inflating: __MACOSX/training/._128_S_4586_ADNI2_M_7607_30T_HC_312675.nii.gz
#   inflating: training/037_S_1078_ADNI1_M_7065_15T_MCI_79837.nii.gz
#   inflating: __MACOSX/training/._037_S_1078_ADNI1_M_7065_15T_MCI_79837.nii.gz
#   inflating: training/053_S_4557_ADNI2_F_8342_30T_MCI_291001.nii.gz
#   inflating: __MACOSX/training/._053_S_4557_ADNI2_F_8342_30T_MCI_291001.nii.gz
#   inflating: training/024_S_4674_ADNI2_M_7799_30T_MCI_300951.nii.gz
#   inflating: __MACOSX/training/._024_S_4674_ADNI2_M_7799_30T_MCI_300951.nii.gz
#   inflating: training/073_S_4853_ADNI2_F_7091_30T_AD_322646.nii.gz
#   inflating: __MACOSX/training/._073_S_4853_ADNI2_F_7091_30T_AD_322646.nii.gz
#   inflating: training/114_S_0166_ADNI1_F_7255_15T_HC_39809.nii.gz
#   inflating: __MACOSX/training/._114_S_0166_ADNI1_F_7255_15T_HC_39809.nii.gz
#   inflating: training/016_S_4887_ADNI2_M_7388_30T_AD_326635.nii.gz
#   inflating: __MACOSX/training/._016_S_4887_ADNI2_M_7388_30T_AD_326635.nii.gz
#   inflating: training/941_S_4376_ADNI2_F_7667_30T_HC_277667.nii.gz
#   inflating: __MACOSX/training/._941_S_4376_ADNI2_F_7667_30T_HC_277667.nii.gz
#   inflating: training/027_S_4802_ADNI2_M_8336_30T_AD_321466.nii.gz
#   inflating: __MACOSX/training/._027_S_4802_ADNI2_M_8336_30T_AD_321466.nii.gz
#   inflating: training/041_S_0282_ADNI1_M_7231_15T_MCI_39485.nii.gz
#   inflating: __MACOSX/training/._041_S_0282_ADNI1_M_7231_15T_MCI_39485.nii.gz
#   inflating: training/037_S_0182_ADNI1_F_6368_15T_MCI_65133.nii.gz
#   inflating: __MACOSX/training/._037_S_0182_ADNI1_F_6368_15T_MCI_65133.nii.gz
#   inflating: training/128_S_0545_ADNI1_M_7190_15T_HC_68999.nii.gz
#   inflating: __MACOSX/training/._128_S_0545_ADNI1_M_7190_15T_HC_68999.nii.gz
#   inflating: training/130_S_4343_ADNI2_M_7973_30T_HC_267761.nii.gz
#   inflating: __MACOSX/training/._130_S_4343_ADNI2_M_7973_30T_HC_267761.nii.gz
#   inflating: training/072_S_4445_ADNI2_M_8386_30T_MCI_280556.nii.gz
#   inflating: __MACOSX/training/._072_S_4445_ADNI2_M_8386_30T_MCI_280556.nii.gz
#   inflating: training/036_S_4491_ADNI2_M_8415_30T_HC_283932.nii.gz
#   inflating: __MACOSX/training/._036_S_4491_ADNI2_M_8415_30T_HC_283932.nii.gz
#   inflating: training/141_S_1231_ADNI1_F_8370_15T_MCI_64434.nii.gz
#   inflating: __MACOSX/training/._141_S_1231_ADNI1_F_8370_15T_MCI_64434.nii.gz
#   inflating: training/003_S_4900_ADNI2_F_5991_30T_HC_326633.nii.gz
#   inflating: __MACOSX/training/._003_S_4900_ADNI2_F_5991_30T_HC_326633.nii.gz
#   inflating: training/073_S_4762_ADNI2_M_7381_30T_HC_315318.nii.gz
#   inflating: __MACOSX/training/._073_S_4762_ADNI2_M_7381_30T_HC_315318.nii.gz
#   inflating: training/072_S_4539_ADNI2_F_6648_30T_MCI_296335.nii.gz
#   inflating: __MACOSX/training/._072_S_4539_ADNI2_F_6648_30T_MCI_296335.nii.gz
#   inflating: training/153_S_4139_ADNI2_F_7066_30T_HC_250662.nii.gz
#   inflating: __MACOSX/training/._153_S_4139_ADNI2_F_7066_30T_HC_250662.nii.gz
#   inflating: training/130_S_4250_ADNI2_M_7859_30T_MCI_261071.nii.gz
#   inflating: __MACOSX/training/._130_S_4250_ADNI2_M_7859_30T_MCI_261071.nii.gz
#   inflating: training/057_S_4888_ADNI2_M_7485_30T_MCI_322359.nii.gz
#   inflating: __MACOSX/training/._057_S_4888_ADNI2_M_7485_30T_MCI_322359.nii.gz
#   inflating: training/003_S_4152_ADNI2_M_6082_30T_AD_255415.nii.gz
#   inflating: __MACOSX/training/._003_S_4152_ADNI2_M_6082_30T_AD_255415.nii.gz
#   inflating: training/128_S_0611_ADNI1_F_7201_15T_MCI_69031.nii.gz
#   inflating: __MACOSX/training/._128_S_0611_ADNI1_F_7201_15T_MCI_69031.nii.gz
#   inflating: training/130_S_2373_ADNIGO_F_7914_30T_MCI_234667.nii.gz
#   inflating: __MACOSX/training/._130_S_2373_ADNIGO_F_7914_30T_MCI_234667.nii.gz
#   inflating: training/067_S_4072_ADNI2_F_6242_30T_MCI_296322.nii.gz
#   inflating: __MACOSX/training/._067_S_4072_ADNI2_F_6242_30T_MCI_296322.nii.gz
#   inflating: training/126_S_4507_ADNI2_M_7823_30T_MCI_283925.nii.gz
#   inflating: __MACOSX/training/._126_S_4507_ADNI2_M_7823_30T_MCI_283925.nii.gz
#   inflating: training/036_S_4715_ADNI2_F_5664_30T_MCI_305485.nii.gz
#   inflating: __MACOSX/training/._036_S_4715_ADNI2_F_5664_30T_MCI_305485.nii.gz
#   inflating: training/021_S_4558_ADNI2_F_7007_30T_HC_312842.nii.gz
#   inflating: __MACOSX/training/._021_S_4558_ADNI2_F_7007_30T_HC_312842.nii.gz
#   inflating: training/029_S_4585_ADNI2_M_6550_30T_HC_300942.nii.gz
#   inflating: __MACOSX/training/._029_S_4585_ADNI2_M_6550_30T_HC_300942.nii.gz
#   inflating: training/130_S_0423_ADNI1_M_7948_15T_MCI_39133.nii.gz
#   inflating: __MACOSX/training/._130_S_0423_ADNI1_M_7948_15T_MCI_39133.nii.gz
#   inflating: training/007_S_1304_ADNI1_F_7488_30T_AD_59918.nii.gz
#   inflating: __MACOSX/training/._007_S_1304_ADNI1_F_7488_30T_AD_59918.nii.gz
#   inflating: training/007_S_4387_ADNI2_F_7616_30T_HC_272695.nii.gz
#   inflating: __MACOSX/training/._007_S_4387_ADNI2_F_7616_30T_HC_272695.nii.gz
#   inflating: training/023_S_0855_ADNI1_M_7575_30T_MCI_31517.nii.gz
#   inflating: __MACOSX/training/._023_S_0855_ADNI1_M_7575_30T_MCI_31517.nii.gz
#   inflating: training/011_S_4949_ADNI2_F_7813_30T_AD_337436.nii.gz
#   inflating: __MACOSX/training/._011_S_4949_ADNI2_F_7813_30T_AD_337436.nii.gz
#   inflating: training/027_S_0404_ADNI1_F_8794_29T_AD_34194.nii.gz
#   inflating: __MACOSX/training/._027_S_0404_ADNI1_F_8794_29T_AD_34194.nii.gz
#   inflating: training/094_S_1314_ADNI1_F_8085_15T_MCI_63195.nii.gz
#   inflating: __MACOSX/training/._094_S_1314_ADNI1_F_8085_15T_MCI_63195.nii.gz
#   inflating: training/027_S_0850_ADNI1_M_7821_15T_AD_48995.nii.gz
#   inflating: __MACOSX/training/._027_S_0850_ADNI1_M_7821_15T_AD_48995.nii.gz
#   inflating: training/013_S_4579_ADNI2_M_8509_30T_HC_297651.nii.gz
#   inflating: __MACOSX/training/._013_S_4579_ADNI2_M_8509_30T_HC_297651.nii.gz
#   inflating: training/011_S_0021_ADNI1_F_7268_15T_HC_32331.nii.gz
#   inflating: __MACOSX/training/._011_S_0021_ADNI1_F_7268_15T_HC_32331.nii.gz
#   inflating: training/023_S_4035_ADNI2_F_7285_30T_MCI_297300.nii.gz
#   inflating: __MACOSX/training/._023_S_4035_ADNI2_F_7285_30T_MCI_297300.nii.gz
#   inflating: training/021_S_2125_ADNIGO_F_7825_30T_MCI_222796.nii.gz
#   inflating: __MACOSX/training/._021_S_2125_ADNIGO_F_7825_30T_MCI_222796.nii.gz
#   inflating: training/131_S_1301_ADNI1_F_7235_30T_HC_71693.nii.gz
#   inflating: __MACOSX/training/._131_S_1301_ADNI1_F_7235_30T_HC_71693.nii.gz
#   inflating: training/041_S_4060_ADNI2_M_8452_30T_HC_241342.nii.gz
#   inflating: __MACOSX/training/._041_S_4060_ADNI2_M_8452_30T_HC_241342.nii.gz
#   inflating: training/123_S_4780_ADNI2_F_7031_30T_MCI_312845.nii.gz
#   inflating: __MACOSX/training/._123_S_4780_ADNI2_F_7031_30T_MCI_312845.nii.gz
#   inflating: training/094_S_1188_ADNI1_F_8134_15T_MCI_66050.nii.gz
#   inflating: __MACOSX/training/._094_S_1188_ADNI1_F_8134_15T_MCI_66050.nii.gz
#   inflating: training/024_S_4186_ADNI2_M_7450_30T_MCI_255408.nii.gz
#   inflating: __MACOSX/training/._024_S_4186_ADNI2_M_7450_30T_MCI_255408.nii.gz
#   inflating: training/137_S_0443_ADNI1_M_6315_15T_MCI_46621.nii.gz
#   inflating: __MACOSX/training/._137_S_0443_ADNI1_M_6315_15T_MCI_46621.nii.gz
#   inflating: training/128_S_0522_ADNI1_M_7002_15T_HC_68982.nii.gz
#   inflating: __MACOSX/training/._128_S_0522_ADNI1_M_7002_15T_HC_68982.nii.gz
#   inflating: training/126_S_0709_ADNI1_M_8392_15T_MCI_38963.nii.gz
#   inflating: __MACOSX/training/._126_S_0709_ADNI1_M_8392_15T_MCI_38963.nii.gz
#   inflating: training/941_S_4255_ADNI2_M_7254_30T_HC_261061.nii.gz
#   inflating: __MACOSX/training/._941_S_4255_ADNI2_M_7254_30T_HC_261061.nii.gz
#   inflating: training/073_S_0518_ADNI1_M_6945_15T_MCI_39908.nii.gz
#   inflating: __MACOSX/training/._073_S_0518_ADNI1_M_6945_15T_MCI_39908.nii.gz
#   inflating: training/002_S_0816_ADNI1_M_7087_15T_AD_40730.nii.gz
#   inflating: __MACOSX/training/._002_S_0816_ADNI1_M_7087_15T_AD_40730.nii.gz
#   inflating: training/098_S_0172_ADNI1_F_7069_15T_HC_65756.nii.gz
#   inflating: __MACOSX/training/._098_S_0172_ADNI1_F_7069_15T_HC_65756.nii.gz
#   inflating: training/116_S_0361_ADNI1_M_7458_15T_MCI_59752.nii.gz
#   inflating: __MACOSX/training/._116_S_0361_ADNI1_M_7458_15T_MCI_59752.nii.gz
#   inflating: training/130_S_4730_ADNI2_F_8118_30T_AD_308046.nii.gz
#   inflating: __MACOSX/training/._130_S_4730_ADNI2_F_8118_30T_AD_308046.nii.gz
#   inflating: training/073_S_0386_ADNI1_F_7244_15T_HC_49679.nii.gz
#   inflating: __MACOSX/training/._073_S_0386_ADNI1_F_7244_15T_HC_49679.nii.gz
#   inflating: training/035_S_4256_ADNI2_F_6286_30T_MCI_272819.nii.gz
#   inflating: __MACOSX/training/._035_S_4256_ADNI2_F_6286_30T_MCI_272819.nii.gz
#   inflating: training/021_S_0178_ADNI1_M_6484_15T_MCI_33798.nii.gz
#   inflating: __MACOSX/training/._021_S_0178_ADNI1_M_6484_15T_MCI_33798.nii.gz
#   inflating: training/123_S_4526_ADNI2_M_7950_30T_AD_285120.nii.gz
#   inflating: __MACOSX/training/._123_S_4526_ADNI2_M_7950_30T_AD_285120.nii.gz
#   inflating: training/024_S_0985_ADNI1_M_8170_15T_HC_62714.nii.gz
#   inflating: __MACOSX/training/._024_S_0985_ADNI1_M_8170_15T_HC_62714.nii.gz
#   inflating: training/009_S_1354_ADNI1_F_5896_15T_AD_60442.nii.gz
#   inflating: __MACOSX/training/._009_S_1354_ADNI1_F_5896_15T_AD_60442.nii.gz
#   inflating: training/129_S_4073_ADNI2_M_7629_30T_MCI_241399.nii.gz
#   inflating: __MACOSX/training/._129_S_4073_ADNI2_M_7629_30T_MCI_241399.nii.gz
#   inflating: training/029_S_4279_ADNI2_M_8388_30T_HC_267756.nii.gz
#   inflating: __MACOSX/training/._029_S_4279_ADNI2_M_8388_30T_HC_267756.nii.gz
#   inflating: training/073_S_4739_ADNI2_M_6521_30T_HC_308103.nii.gz
#   inflating: __MACOSX/training/._073_S_4739_ADNI2_M_6521_30T_HC_308103.nii.gz
#   inflating: training/128_S_0715_ADNI1_F_8009_15T_MCI_89787.nii.gz
#   inflating: __MACOSX/training/._128_S_0715_ADNI1_F_8009_15T_MCI_89787.nii.gz
#   inflating: training/116_S_4199_ADNI2_M_5906_30T_MCI_254785.nii.gz
#   inflating: __MACOSX/training/._116_S_4199_ADNI2_M_5906_30T_MCI_254785.nii.gz
#   inflating: training/072_S_2026_ADNIGO_F_8262_30T_MCI_223220.nii.gz
#   inflating: __MACOSX/training/._072_S_2026_ADNIGO_F_8262_30T_MCI_223220.nii.gz
#   inflating: training/003_S_4350_ADNI2_M_7296_30T_HC_272721.nii.gz
#   inflating: __MACOSX/training/._003_S_4350_ADNI2_M_7296_30T_HC_272721.nii.gz
#   inflating: training/116_S_4209_ADNI2_F_7779_30T_AD_254813.nii.gz
#   inflating: __MACOSX/training/._116_S_4209_ADNI2_F_7779_30T_AD_254813.nii.gz
#   inflating: training/057_S_0643_ADNI1_F_7146_15T_HC_34724.nii.gz
#   inflating: __MACOSX/training/._057_S_0643_ADNI1_F_7146_15T_HC_34724.nii.gz
#   inflating: training/033_S_4176_ADNI2_M_8412_30T_HC_254802.nii.gz
#   inflating: __MACOSX/training/._033_S_4176_ADNI2_M_8412_30T_HC_254802.nii.gz
#   inflating: training/029_S_1215_ADNI1_M_7856_15T_MCI_60745.nii.gz
#   inflating: __MACOSX/training/._029_S_1215_ADNI1_M_7856_15T_MCI_60745.nii.gz
#   inflating: training/021_S_4402_ADNI2_F_7295_30T_MCI_272816.nii.gz
#   inflating: __MACOSX/training/._021_S_4402_ADNI2_F_7295_30T_MCI_272816.nii.gz
#   inflating: training/073_S_4360_ADNI2_F_5951_30T_MCI_267766.nii.gz
#   inflating: __MACOSX/training/._073_S_4360_ADNI2_F_5951_30T_MCI_267766.nii.gz
#   inflating: training/123_S_0050_ADNI1_M_7770_15T_MCI_64389.nii.gz
#   inflating: __MACOSX/training/._123_S_0050_ADNI1_M_7770_15T_MCI_64389.nii.gz
#   inflating: training/031_S_4032_ADNI2_F_7031_30T_HC_235655.nii.gz
#   inflating: __MACOSX/training/._031_S_4032_ADNI2_F_7031_30T_HC_235655.nii.gz
#   inflating: training/067_S_0607_ADNI1_F_7827_30T_MCI_34865.nii.gz
#   inflating: __MACOSX/training/._067_S_0607_ADNI1_F_7827_30T_MCI_34865.nii.gz

# %% [markdown]
# # Imports and Parameters

# %%
import os
import torch
import torch.nn as nn
import numpy as np
import nibabel as nib
import matplotlib.pyplot as plt

from glob import glob
from os.path import join
from os import listdir
from pathlib import Path
from collections import OrderedDict

from tqdm import tqdm

from PIL import Image

from torch import optim
from torch.utils.data.dataset import Dataset
from torch.utils.data.dataloader import DataLoader
from torch.utils.data.sampler import SubsetRandomSampler
from torch.utils.data import DataLoader
from torch.nn.modules.loss import L1Loss
from torch.nn.modules.loss import MSELoss
from torchsummary import summary

from sklearn.decomposition import PCA
from sklearn.manifold import TSNE


PCA_PARAMETERS = {
    "n_components":2,
    "copy":True,
    "whiten":False,
    "svd_solver": "auto",
    "tol": 0,
    "iterated_power": "auto",
    "random_state": 0
}

NETWORK_LENGTH = 2
NETWORK_DEPTH = 4
FEATURE_SIZE = 2
BATCH_SIZE = 32
WORKERS = 4
EPOCHS = 50

def numpy_from_tensor(x):
  return x.detach().cpu().numpy()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-543098fdc0f4> in <module>
#       1 import os
# ----> 2 import torch
#       3 import torch.nn as nn
#       4 import numpy as np
#       5 import nibabel as nib
#
# ModuleNotFoundError: No module named 'torch'

# %% [markdown]
# # Dataset Loader

# %%
class NiftyDataset(Dataset):
  '''
    Class that loads nii files, resizes them to 96x96 and feeds them
  '''
  def __init__(self,root_dir):
    '''
      root_dir - string - path towards the folder containg the data
    '''
    # Save the root_dir as a class variable
    self.root_dir = root_dir
    # Save the filenames in the root_dir as a class variable
    self.filenames = listdir(self.root_dir)
  
  def __len__(self):
    return len(self.filenames)
  
  def __getitem__(self,idx):
    # Fetch file filename
    img_name = self.filenames[idx]
    # Load the nifty image
    img = nib.load(os.path.join(self.root_dir,img_name))
    # Get the voxel values as a numpy array
    img = np.array(img.get_data())
    # Expanding the array with 1 new dimension as feature channel
    img = np.expand_dims(img, 0)

    return img

# Loading the data
training_dataset = NiftyDataset(
    root_dir=join("/content/training/")
)
testing_dataset = NiftyDataset(
    root_dir=join("/content/testing/")
)

# Create the required DataLoaders for training and testing
training_loader = DataLoader(
    training_dataset,
    shuffle=True,
    batch_size=BATCH_SIZE,
    num_workers=WORKERS,
    drop_last=True
)
testing_loader = DataLoader(
    testing_dataset,
    shuffle=False,
    batch_size=BATCH_SIZE,
    num_workers=WORKERS,
    drop_last=True
)

# Show a random image from training
plt.imshow(np.squeeze(next(iter(training_dataset))), cmap="gray")
plt.axis('off')
plt.show()

# %% [markdown]
# # Traning the network
#
# Code the training loop for the network:
# *   Loss function needs to be L1 (MAE) + L2 (MSE)
# *   Compute the predictions
# *   Compute the gradients
# *   Optimize the variables
# *   Compute test predictions
# *   Compute average test dataset loss

# %%
def display_results(x, x_hat): 
  x = numpy_from_tensor(x[0])
  x_hat = numpy_from_tensor(x_hat[0])

  plt.figure()
  f, axarr = plt.subplots(1, 3) 

  axarr[0].imshow(np.squeeze(x), cmap="gray") 
  axarr[0].axis('off')
  axarr[0].title.set_text("Input")
  
  axarr[1].imshow(np.squeeze(x-x_hat), cmap="gray")
  axarr[1].axis('off')
  axarr[1].title.set_text("Residual")
  
  axarr[2].imshow(np.squeeze(x_hat), cmap="gray")
  axarr[2].axis('off')
  axarr[2].title.set_text("Reconstruction")
  
  plt.show()

def train_network(training_loader, testing_loader, network):
  device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

  network.cuda(device)

  optimizer = optim.Adam(network.parameters(), lr=0.001)

  #TODO: Initialize the losses

  # Train the network
  for epoch in range(EPOCHS):
    for x in training_loader:
      # Move input to device
      x = x.to(device, dtype=torch.float)

      # Zero the parameter gradients
      optimizer.zero_grad()

      # TODO:Forward pass

      # TODO:Calculate losses

      # TODO:Back-propagation of gradients

      # TODO:Optimize

    if epoch % 10 == 0:
      # TODO:Initialize loss acumulators

      for i, x in enumerate(testing_loader):
        x = x.to(device, dtype=torch.float)

        # TODO:Forward pass

        # TODO:Calculate losses
    
      print(
          "==== Epoch: " + str(epoch) + 
          " | L1 loss: " + str(numpy_from_tensor(l1_test_loss/i)) + 
          " | L2 loss: " + str(numpy_from_tensor(l2_test_loss/i)) +
          " | Total Loss: " + str(numpy_from_tensor((l1_test_loss+l2_test_loss)/i))+ " =====")
      display_results(x, x_hat)
  return network

# %% [markdown]
# # Network structure
# The network will be composed mainly of _Residual blocks_ which are coded for you bellow and _Linear_ layers.
#
# The structure is _Encoder_ -> _Code processor_ -> _Decoder_ where the _Code processor_ will will be changed to fit different types of networks.
#
# The _Encoder_ and the _Decoder_ will be __fully convolutional neural networks__.
#
# When coding please keep in mind that you should code in a modula way.

# %% [markdown]
# # Residual block
#
# For the purpose of this tutorial you should aim to use the *ResBlock* as the bulding block of your _Encoder_ and _Decoder_. It should **not** be used in any of the *Code Processors*.

# %%
class ResBlock(nn.Module):
  def __init__(self, in_channels, out_channels, mode="level"):
    '''
      in_channels - integer - the number of feature channels the first 
                              convolution will receive
      out_channels - integer - the number of feature channels the last
                               convolution will output
      mode - string - defines what the block will do
           - "upsample" means the block wil double the spatial size
           - "downsample" means the block will halve the spatial size
           - "level" means the block will not change the spatial dimension
    '''
    super(ResBlock, self).__init__()

    if mode == "upsample":
      self.conv1 = nn.ConvTranspose2d(
          in_channels=in_channels, 
          out_channels=out_channels, 
          kernel_size=4, 
          stride=2 ,
          padding=1, 
      )

      self.conv1b = nn.ConvTranspose2d(
          in_channels=in_channels, 
          out_channels=out_channels, 
          kernel_size=4, 
          stride=2 ,
          padding=1, 
      )
    else:  
      self.conv1 = nn.Conv2d(
          in_channels=in_channels, 
          out_channels=out_channels, 
          kernel_size=3, 
          stride=2 if mode == "downsample" else 1,
          padding=1, 
      )

      self.conv1b = nn.Conv2d(
          in_channels=in_channels, 
          out_channels=out_channels, 
          kernel_size=3, 
          stride=2 if mode == "downsample" else 1,
          padding=1, 
      )
    
    self.conv2 =  nn.Conv2d(
        in_channels=out_channels, 
        out_channels=out_channels, 
        kernel_size=3, 
        stride=1,
        padding=1, 
    ) 
    
    self.activation = nn.LeakyReLU(inplace=True)

    torch.nn.init.xavier_normal_(self.conv1.weight.data)
    torch.nn.init.xavier_normal_(self.conv1b.weight.data)
    torch.nn.init.xavier_normal_(self.conv2.weight.data)

  def forward(self, x):
    out = self.conv1(x)
    out = self.activation(out)

    skip = self.conv1b(x)

    out = self.conv2(out)
    out += skip

    out = self.activation(out)

    return out

# %% [markdown]
# # Encoder
#
# The *Encoder* is a fully convolutional neural network that that **takes** a tensor of size **(-1, 1, 64, 64)** and **outputs** a tensor of size **(-1, 32, 4, 4)**.
#
# ----
#
# To do:
# *   Use **only** *ResBlocks* to **complete** the network
# *   While doing so you **need** to modify the *in_chanels* and *feature_size*

# %%
class Encoder(nn.Module):
  def __init__(self, in_channels, depth, length, feature_size):
    super(Encoder, self).__init__()
    encoder = OrderedDict()

    for l in range(0, length - 1, 1):
      #TODO:Create a ResBlock to have the desired initial
      #     feature size
      encoder["encoder-depth_0-length_"+str(l)]=

      in_channels =       
    for d in range(1, depth + 1, 1):
      #TODO:Modify the in_chanels and feature_size accoringly
      in_channels = 
      feature_size =
      #TODO:Create a ResBlock to downsample to the desired
      #     feature size
      encoder["encoder-depth_"+str(d)+"-downsample"]=

      for l in range(0, length - 1, 1):
        #TODO:Create a ResBlock to further process the data
        #     keep it at the same feature depth and resolution
        encoder["encoder-depth_"+str(d)+"-length_"+str(l)]=

    self.encoder = nn.Sequential(encoder)

  def forward(self, x):
    return self.encoder(x)

# %% [markdown]
# # Decoder
#
# The *Decoder* is a fully convolutional network that **takes** a tensor of size **(-1, 32, 4, 4)** and **outputs** a tensor of size **(-1, 1, 64, 64)**.
#
# ----
#
# To do :
# *   Use **only** *ResBlocks* to **complete** the network
# *   While doing so you **need** to modify *feature_size* and *in_channels*

# %%
class Decoder(nn.Module):
  def __init__(self, in_channels, depth, length, reconstruction_channels):
    super(Decoder, self).__init__()
    decoder = OrderedDict()

    #TODO:Calculate the initial feature_size
    feature_size =

    for d in range(depth, 0, -1):
      #TODO:Create a ResBlock to upsample to the desired feature
      #     size
      decoder["decoder-depth_"+str(d)+"-upsample"]=

      for l in range(0, length - 1, 1):
        #TODO:Create a ResBlock to further process the data keep
        #     it at the same feature depth and resolution
        decoder["decoder-depth_"+str(d)+"-length_"+str(l)]=
        
      #TODO:Modify the in_chanels and feature_size accoringly
      in_channels = 
      feature_size = 

    #TODO:Create the a ResBlock that outputs the required number
    #     of channels for the output
    decoder["decoder-depth_0-reconstruction"]=

    self.decoder = nn.Sequential(decoder)

  def forward(self,x):
    return self.decoder(x)

# %% [markdown]
# # Unsupervised Network
# The *Unsupervised Network* is the class that glues all the components (*Encoder*, *Code Processor*, *Decoder*) that you will use togheter.
#
# Its aim is to take an image and give you the reconstruction. It should also be able to encode image, and decode codes.
#
# ----
#
# To do:
# *   **Call** the code processor to process the *Encoder's* output so that is passed to the *Decoder*
# *   **Call** the needed methods to procces the latent representation of the *Encoder* and get a **code**, and a **code** to get a **spatial latent reprentation**
#
# ----
#
# Tip:
# *   Any *Code processor* will **have** an **encode** and **decode** method

# %%
class UnsupervisedNetwork(nn.Module):
  def __init__(self, encoder, code_processor, decoder):
    super(UnsupervisedNetwork, self).__init__()
    self.encoder = encoder
    self.code_processor = code_processor
    self.decoder = decoder

  def forward(self, x):
    x = self.encoder(x)
    
    #TODO:Process encoder's latent representation
    #     to go through the code and get the desired
    #     input for the decoder
    x =
    
    x = self.decoder(x)

    return x

  def encode(self, x):
    x = self.encoder(x)
    #TODO:Process encoder's latent representation
    #     to obtain the code
    x = 

    return x

  def decode(self, x):
    #TODO:Process a code to get the required input
    #     for the decoder
    x = 
    x = self.decoder(x)
    return x

# %% [markdown]
# # Dense Auto Encoder
# In a *Dense AutoEncoder* the *Code Processor* receives the latent representation of the *Encoder* and then flattens it into a 1D array. Following that it is further compressed until the desired code dimension. Then it decompresses it while keepint it a 1D array. Finally it reshapes it so it can be passed.
#
# ----
#
# To do:
# *   Complete the Dense autoencoder with **Linear** layers
# *   Code the functionality for forward pass, encoding and decoding
#
# ----
#
# Tips:
# *   Look at [flatten layer](https://pytorch.org/docs/stable/nn.html#torch.nn.Flatten) and pay attention to the **start_dim** parameter.
# *   Look at the [view](https://pytorch.org/docs/stable/tensors.html#torch.Tensor.view) method of tensors
# *   Be careful with the feature sizes, you might need to be able to calculate them

# %%
class DenseAECodeProcessor(nn.Module):
  def __init__(self, feature_size, depth, img_sizes, encoding_sizes, decoding_sizes):
    super(DenseAECodeProcessor, self).__init__()

    feature_depth = feature_size * np.power(2, depth)
    img_sizes = [img_size/np.power(2,depth) for img_size in img_sizes]

    flatten_size = int(feature_depth * np.prod(img_sizes))

    ecoding_processor = OrderedDict()

    in_features = flatten_size

    #TODO:Given a list of Linear layers output sizes compress the
    #     feature to the desired code size
    for i in range(len(encoding_sizes)):
      ecoding_processor["ecoding_flatten_" + str(i)] = 
      in_features = 

    self.ecoding_processor = nn.Sequential(ecoding_processor)

    decoding_processor = OrderedDict()

    #TODO:Given a list of Linear layers output sizes decomporess the
    #     feature to the desired size
    for i in range(len(decoding_sizes)):
      decoding_processor["decoding_flatten_" + str(i)] =
      in_features = 
    
    decoding_processor["flatten_" + str(i+1)] =

    self.decoding_processor = nn.Sequential(decoding_processor)

  def forward(self, x):
    #TODO:Remember the sample tensor shape
    self.spatial_shape = 

    #TODO:Prepare encoder's latent representation to be processed 
    #     by the Linear layers
    x = 
    
    x = self.ecoding_processor(x)
    
    x = self.decoding_processor(x)
    
    #TODO:Prepare the tensor to be passed to the decoder
    x = 

    return x

  def encode(self, x):
    #TODO:Prepare encoder's latent representation to be processed 
    #     by the Linear layers
    x = 
    x = self.ecoding_processor(x)
    
    return x

  def decode(self, x):
    x = self.decoding_processor(x)
    #TODO:Prepare the tensor to be passed to the decoder
    x = 

    return x

# %% [markdown]
# Lets now train the network and see what we get!

# %%
network = UnsupervisedNetwork(
  encoder=Encoder(
    in_channels=1, 
    depth=NETWORK_DEPTH, 
    length=NETWORK_LENGTH, 
    feature_size=FEATURE_SIZE
  ),
  code_processor=DenseAECodeProcessor(**{
    "feature_size":FEATURE_SIZE, 
    "depth":NETWORK_DEPTH, 
    "img_sizes":[192,192], 
    "encoding_sizes":[1024,512,256],
    "decoding_sizes":[512,1024],
  }),
  decoder=Decoder(
    in_channels=np.power(FEATURE_SIZE,NETWORK_DEPTH+1), 
    depth=NETWORK_DEPTH, 
    length=NETWORK_LENGTH, 
    reconstruction_channels=1
  ),
)

network = train_network(training_loader, testing_loader, network)

# %% [markdown]
# # Dimensionality reduction visualization
#
# The *dimensionality_reduction_analysis* method given a training dataset loader, a testing dataset loader and a network will show a scatter plot of a 2D PCA dimensionality reduction of training and testing samples.
#
# ----
#
# To do:
# *   Reshape the numpy arrays into the needed shape to be fed into PCA
# *   Project the *training_encodings* into 2D
# *   Project the *testing_encodings* into 2D
#
# ----
#
# Tips
# *    Might wanna look at [numpy.reshape](https://docs.scipy.org/doc/numpy/reference/generated/numpy.reshape.html)

# %%
def dimensionality_reduction_analysis(training_loader, testing_loader, network):
  device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

  network.cuda(device)

  training_encodings = None
  for x in training_loader:
    x = x.to(device, dtype=torch.float)
    x = network.encode(x)
    x = numpy_from_tensor(x)
    training_encodings =  (
        x if training_encodings is None
        else np.concatenate((training_encodings, x), axis=0)
    )
  training_encodings = np.array(training_encodings)
  #TODO:Reshape the data to be fed into PCA
  training_encodings =

  testing_encodings = None
  for x in testing_loader:
    x = x.to(device, dtype=torch.float)
    x = network.encode(x)
    x = numpy_from_tensor(x)
    testing_encodings =  (
        x if testing_encodings is None
        else np.concatenate((testing_encodings, x), axis=0)
    )
  testing_encodings = np.array(testing_encodings)
  #TODO:Reshape the data to be fed into PCA
  testing_encodings = 

  pca = PCA(**PCA_PARAMETERS)
  #TODO:Do dimensionality reduction on training encodings
  training_reduction = 
  #TODO:Do dimensionality reduction on testing encodings
  testing_reduction = 

  fig, ax = plt.subplots()
  ax.scatter(
    x=training_reduction[:,0], 
    y=training_reduction[:,1],
    c="blue",
    label="Training Data"
  )
  ax.scatter(
    x=testing_reduction[:,0], 
    y=testing_reduction[:,1],
    c="red",
    label="Testing Data"
  )
  ax.set_xlabel("Dimension 1")
  ax.set_ylabel("Dimension 2")
  
  min_x = np.min([np.min(training_reduction[:,0]),np.min(testing_reduction[:,0])])
  min_x = min_x - np.abs(min_x*0.25)

  max_x = np.max([np.max(training_reduction[:,0]),np.max(testing_reduction[:,0])])
  max_x = max_x + max_x*0.25
  
  ax.set_xlim(min_x,max_x)
  
  min_y = np.min([np.min(training_reduction[:,1]),np.min(testing_reduction[:,1])])
  min_y = min_y - np.abs(min_y*0.25)

  max_y = np.max([np.max(training_reduction[:,1]),np.max(testing_reduction[:,1])])
  max_y = max_y + max_y*0.25

  ax.set_ylim(min_y,max_y)
  plt.legend(loc = 'best')
  plt.show()
  plt.close()

# %% [markdown]
# Now lets see what we get if we run it!

# %%
dimensionality_reduction_analysis(
  training_loader=training_loader,
  testing_loader=testing_loader,
  network=network
)

# %% [markdown]
# # Interpolation
# The *interpolation_analysis* method given a training dataset loader, a testing dataset loader and a network will show:
# *   An interpolation between two training samples
# *   An interpolation between two testing samples
# *   And two interpolations between training and testing samples
#
# For two encodings ${z}_{1}$ and ${z}_{2}$ and a decoder $D$ interpolation can be defined as: $D({z}_{1}*(1-\alpha)+\alpha*{z}_{2})$
#
# ----
#
# To do:
# *   Calculate alpha based codes
# *   Get the samples based on those codes

# %%
def interpolation_analysis(training_loader, testing_loader, network):
  device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

  network.cuda(device)

  training_batch = next(iter(training_loader))
  training_sample_0 = training_batch[0]
  training_sample_1 = training_batch[1]

  testing_batch = next(iter(testing_loader))
  testing_sample_0 = testing_batch[0]
  testing_sample_1 = testing_batch[1]

  combinations={
      "Training samples":(training_sample_0, training_sample_1),
      "Testing samples": (testing_sample_0, testing_sample_1),
      "Training to Testing 1": (training_sample_0, testing_sample_0),
      "Training to Testing 2": (training_sample_1, testing_sample_1)
  }

  for name, samples in combinations.items():
    sample_0 = samples[0].to(device, dtype=torch.float).unsqueeze(0)
    sample_1 = samples[1].to(device, dtype=torch.float).unsqueeze(0)

    code_0 = network.encode(sample_0)
    code_1 = network.encode(sample_1)
    for i, alpha in enumerate(np.linspace(0,1,5)):
      #TODO:Calcualte the interpolation code
      alpha_code = 
      #TODO:Get the interpolated sample
      alpha_sample = 

      plt.figure()
      f, ax = plt.subplots()
      ax.imshow(np.squeeze(alpha_sample), cmap="gray") 
      ax.axis('off')
      ax.title.set_text(name + " | Interpolation " + str(i))
      plt.show()
      plt.close()

# %% [markdown]
# Now lets see what we get if we run it!

# %%
interpolation_analysis(
  training_loader=training_loader,
  testing_loader=testing_loader,
  network=network
)

# %% [markdown]
# # Experiment design
# Now you need to put everything togheter and make it as a single experiment.
#
# ----
#
# To do:
# *    Compile the network definition, network training, dimensionality reductiona and interpolation analysis into a single method that can be later used.
#
# ----
#
# Tips:
# *   Do not overthink it

# %%
def experiment(code_processor_class, code_processor_parameters, network_depth, network_length, feature_size):
  #TODO:Put togheter the creation of the network, the training 
  #     and two analysis that you have coded up until now. This
  #     method should only **call** the other ones

# %% [markdown]
# Now lets see what we get if we run it!

# %%
experiment(
    code_processor_class=DenseAECodeProcessor, 
    code_processor_parameters={
      "feature_size":FEATURE_SIZE, 
      "depth":NETWORK_DEPTH, 
      "img_sizes":[96, 96], 
      "encoding_sizes":[1024,512,256],
      "decoding_sizes":[512,1024],
    }, 
    network_depth=NETWORK_DEPTH, 
    network_length=NETWORK_LENGTH, 
    feature_size=FEATURE_SIZE,
)

# %% [markdown]
# #Spatial AutoEncoder
# For a *Spatial AutoEncoder* the *Code Processor* only passes the latent representation of the *Encoder* to the *Decoder*
#
# ----
#
# To do:
# *    Code the missing pices
#
# ----
#
# Tips:
# *    Do not overthink it

# %%
class SpatialAECodeProcessor(nn.Module):
    def __init__(self):
      super(SpatialAECodeProcessor, self).__init__()

    def forward(self, x):
      #TODO:Code any tensor processing if needed
      
    def encode(self, x):
      #TODO:Code any tensor processing if needed

    def decode(self, x):
      #TODO:Code any tensor processing if needed

# %% [markdown]
# Now lets see what we get if we run it!

# %%
experiment(
    code_processor_class=SpatialAECodeProcessor, 
    code_processor_parameters={}, 
    network_depth=NETWORK_DEPTH, 
    network_length=NETWORK_LENGTH, 
    feature_size=FEATURE_SIZE,
)

# %% [markdown]
# # Training Method (AE and VAE)
# It is time to now modify most of the methods you wrote and enable them to **also** receive a **Variational AutoEncoder**.
#
#
# The KL divergence is:
#
# $D_{K L}[N(\mu(X), \Sigma(X)) \| N(0,1)]=\frac{1}{2} \sum_{k}\left(\exp (\Sigma(X))+\mu^{2}(X)-1-\Sigma(X)\right)$
#
#
# ----
#
# To do:
# *   Modify the signature of the method if needed
# *   Modify the call to the forward pass
# *   Calculate the loss
# *   Calculate the test loss
# *   Change between training and testing modes
#
# ----
#
# Tips:
# *   Do not forget the method should be able to receive **either** a VAE or an AE
# *   A **VAE** behaves **differently** in training and inference/testing/validation mode so you **can assume** that the VAEs will have a **.set_is_training()** method

# %%
#TODO:Modify the signature if needed
def train_network(training_loader, testing_loader, network):
  device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

  network.cuda(device)

  optimizer = optim.Adam(network.parameters(), lr=0.001)

  l1_loss = L1Loss()
  l2_loss = MSELoss()

  # Train the network
  for epoch in range(EPOCHS):
    for x in training_loader:
      # Move input to device
      x = x.to(device, dtype=torch.float)

      # Zero the parameter gradients
      optimizer.zero_grad()

      #TODO:Forward pass such that it can take either
      #     a VAE or an AE

      #TODO:Calculate loss such that it can take either
      #     a VAE or an AE

      # Back-propagation of gradients
      loss.backward()

      # Optimize
      optimizer.step()

    if epoch % 10 == 0:
      #TODO:Turn the network in testing mode

      #TODO:Initialize accumulators
      for i, x in enumerate(testing_loader):
        x = x.to(device, dtype=torch.float)

        #TODO:Forward pass such that it can take either
        #     a VAE or an AE
        
        #TODO:Calculate loss such that it can take either
        #     a VAE or an AE
            
      print(
          "==== Epoch: " + str(epoch) + 
          " | L1 loss: " + str(numpy_from_tensor(l1_test_loss/i)) + 
          " | L2 loss: " + str(numpy_from_tensor(l2_test_loss/i)) +
          " | KL loss: " + str(numpy_from_tensor(kl_test_loss/i)) +
          " | Total Loss: " + str(numpy_from_tensor((l1_test_loss+l2_test_loss+kl_test_loss)/i))+ " =====")
      display_results(x, x_hat)
    #TODO:Turn the network back into training mode
    
  return network

# %% [markdown]
# # Unsupervised Network (AE and VAE)
# You need to modify the class *UnsupervisedNetwork* such that is able to hold either a AE or a VAE.
#
# ----
#
# To do:
# *    Modify the signature of the *__init__* if needed
# *    Modify the return elements of that the *code_processor()* returns since a VAE includes also a mean and a logvar besides the code
# *    Same as above for the forward pass
# *    Implement a class variable that tells us if the network is training or not
#
# ----
#
# Tips:
# *    Do not overthink it

# %%
class UnsupervisedNetwork(nn.Module):
  #TODO:Modify the signature if needed
  def __init__(self, encoder, code_processor, decoder):
    super(UnsupervisedNetwork, self).__init__()
    #TODO:Modify the class variables if needed
  
    self.encoder = encoder
    self.code_processor = code_processor
    self.decoder = decoder

  def forward(self, x):
    x = self.encoder(x)
    
    #TODO:Process encoder's latent representation
    #     to go through the code and get the desired
    #     input for the decoder
    
    x = self.decoder(x)

    #TODO:change the output such that it matches
    #     either a VAE or an AE
    
  def encode(self, x):
    x = self.encoder(x)
    x = self.code_processor.encode(x)

    return x

  def decode(self, x):
    x = self.code_processor.decode(x)
    x = self.decoder(x)
    return x
  
  #TODO:You might need a function to change
  #     if a network is training or not 
  def set_is_training(self):

# %% [markdown]
# # Experiment design (AE and VAE)
# You need to modify the method *experiment* such that it si able to take either a AE or a VAE.
#
# ----
#
# To do:
# *    Modify the signatures of the methods to adhere to all the modifications that you made
#
# ----
#
# Tips:
# *    Do not overthink it

# %%
#TODO:Change the signature if needed and any other signature
def experiment(code_processor_class, code_processor_parameters, network_depth, network_length, feature_size):
  network = UnsupervisedNetwork(
    encoder=Encoder(
      in_channels=1, 
      depth=network_depth, 
      length=network_length, 
      feature_size=feature_size
    ),
    code_processor=code_processor_class(**code_processor_parameters),
    decoder=Decoder(
      in_channels=np.power(feature_size,network_depth+1), 
      depth=network_depth, 
      length=network_length, 
      reconstruction_channels=1
    ),
  )

  train_network(
      training_loader=training_loader,
      testing_loader=testing_loader,
      network=network,
  )

  dimensionality_reduction_analysis(
      training_loader=training_loader,
      testing_loader=testing_loader,
      network=network
  )

  interpolation_analysis(
      training_loader=training_loader,
      testing_loader=testing_loader,
      network=network,
  )

# %% [markdown]
# # Dense Variational AutoEncoder
# In a *Dense Variational AutoEncoder* the *Code Processor* receives the latent representation of the *Encoder* and then flattens it into a 1D array. Following that it is further compressed until the desired code dimension. Then a **mean** and **logvariance** are estimated and used in the **kernel trick**. The result of the kernel trick is  then decompresses while beeing keept a 1D array. Finally it reshapes it so it can be passed to the *Decoder*.
#
# ----
#
# To do:
# *   Complete the Dense autoencoder with **Linear** layers
# *   Implement the *kernel trick*
# *   Code the functionality for forward pass, encoding and decoding
#
# ----
#
# Tips:
# *   Look at [flatten layer](https://pytorch.org/docs/stable/nn.html#torch.nn.Flatten) and pay attention to the **start_dim** parameter.
# *   Look at the [view](https://pytorch.org/docs/stable/tensors.html#torch.Tensor.view) method of tensors
# *   Be careful with the feature sizes, you might need to be able to calculate them
# *   Might need to use [clamp](https://pytorch.org/docs/stable/torch.html#torch.clamp) on logvars

# %%
class DenseVAECodeProcessor(nn.Module):
  #TODO:Change the signature if needed
  def __init__(self, feature_size, depth, img_sizes, encoding_sizes, decoding_sizes):
    super(DenseVAECodeProcessor, self).__init__()
    self.logvars_upper_bound = 50
    self.logvars_lower_bound = -self.logvars_upper_bound

    feature_depth = feature_size * np.power(2, depth)
    img_sizes = [img_size/np.power(2,depth) for img_size in img_sizes]

    flatten_size = int(feature_depth * np.prod(img_sizes))

    ecoding_processor = OrderedDict()

    in_features = flatten_size

    #TODO:Given a list of Linear layers output sizes compress the
    #     feature to the desired code size
    for i in range(len(encoding_sizes)):
      ecoding_processor["ecoding_flatten_" + str(i)] =
      in_features = 

    self.ecoding_processor = nn.Sequential(ecoding_processor)

    #TODO:Create Linear layers for both logvariance and mean
    self.logvar = 

    self.mu = 

    decoding_processor = OrderedDict()

    #TODO:Given a list of Linear layers output sizes decompress the
    #     code to the needed size for the decoder
    for i in range(len(decoding_sizes)):
      decoding_processor["decoding_flatten_" + str(i)] = 
      in_features = 
    
    decoding_processor["flatten_" + str(i+1)] = nn.Linear(
      in_features=in_features, 
      out_features=flatten_size,
    )

    self.decoding_processor = nn.Sequential(decoding_processor)

  def forward(self, x):
    self.spatial_shape = x.shape[1:]

    x = torch.flatten(x, start_dim=1)
    x = self.ecoding_processor(x)
    
    #TODO:Code the reparametrisation trick you will need to
    #     you need to take into account if the network
    #     is training or not
    logvar = 

    mu = 

    
    x = self.decoding_processor(x)
    x = x.view((-1,) + self.spatial_shape)

    return x, mu, logvar

  def encode(self, x):
    x = torch.flatten(x, start_dim=1)
    x = self.ecoding_processor(x)
    #TODO:Code the necessary processing of the latent 
    #     representation
    x = 

    return x

  def decode(self, x):
    x = self.decoding_processor(x)
    x = x.view((-1,)+self.spatial_shape)

    return x
  
  #TODO:You might need a function to change
  #     if a network is training or not
  def set_is_training(self):

# %% [markdown]
# Now lets see what we get if we run it!

# %%
#TODO:Make any signatures changes that you did in
#     the last cell that edited this method
experiment(
    code_processor_class=DenseVAECodeProcessor, 
    code_processor_parameters={
      "feature_size":FEATURE_SIZE, 
      "depth":NETWORK_DEPTH, 
      "img_sizes":[192,192], 
      "encoding_sizes":[1024,512,256],
      "decoding_sizes":[512,1024],
    }, 
    network_depth=NETWORK_DEPTH, 
    network_length=NETWORK_LENGTH, 
    feature_size=FEATURE_SIZE,
)

# %% [markdown]
# # Spatial Variational AutoEncoder
# In a *Spatial Variational AutoEncoder* the *Code Processor* receives the latent representation of the *Encoder* and then a **mean** and **logvariance** are estimated and used in the **kernel trick**. The result of the kernel trick is then passed to the *Decoder*.
#
# ----
#
# To do:
# *   Estimate the mean and variance
# *   Implement the *kernel trick*
# *   Code the functionality for forward pass, encoding and decoding
#
# ----
#
# Tips:
# *   Might need to use [clamp](https://pytorch.org/docs/stable/torch.html#torch.clamp) on logvars

# %%
class SpatialVAECodeProcessor(nn.Module):
    #TODO:Change the signature if needed
    def __init__(self, feature_size, depth):
      super(SpatialVAECodeProcessor, self).__init__()
      self.logvars_upper_bound = 50
      self.logvars_lower_bound = -self.logvars_upper_bound
      
      
      feature_depth = feature_size * np.power(2, depth)
      
      #TODO:Create 2D Convolutional layers for the logvar
      #     and mean
      self.logvar =

      self.mu = 

    def forward(self, x):
      #TODO:Code the reparametrisation trick you will need to
      #     you need to take into account if the network
      #     is training or not
      logvar = 

      mu = 


      return x, mu, logvar
    
    def encode(self, x):
      #TODO:Code the necessary processing of the latent
      #     representation
      x = 
      return x

    def decode(self, x):
      return x

    #TODO:You might need a function to change
    #     if a network is training or not
    def set_is_training(self, is_training):
      self.is_training = is_training

# %% [markdown]
# Now lets see what we get if we run it!

# %%
#TODO:Make any signatures changes that you did in
#     the last cell that edited this method
experiment(
    code_processor_class=SpatialVAECodeProcessor, 
    code_processor_parameters={
      "feature_size":FEATURE_SIZE, 
      "depth":NETWORK_DEPTH+1, 
    }, 
    network_depth=NETWORK_DEPTH+1, 
    network_length=NETWORK_LENGTH, 
    feature_size=FEATURE_SIZE,
)
